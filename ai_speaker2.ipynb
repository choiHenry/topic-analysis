# %% [markdown]
# <a href="https://colab.research.google.com/github/choiHenry/topic-analysis/blob/master/ai_speaker2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import requests
from bs4 import BeautifulSoup

# %%
def getPcode(page):
    pCodeList = []
    for i in range(1,page+1):
        print(i,"페이지 입니다")
        headers = {
            "Accept": "text/html, */*; q=0.01",
            "Accept-Encoding": "gzip, deflate",
            "Accept-Language": "en-US,en;q=0.9,ko;q=0.8",
            "Connection": "keep-alive",
            "Content-Length": "633",
            "Content-Type": "application/x-www-form-urlencoded",
            "Cookie": "userAccessIP=147.47.133.48; userAccessTime=2019-08-07+12%3A20%3A47; cookPrevViewCategory=12325478%7C12218103; OAX=AdJ2+Fz+7nUAA1WR; danawa-loggingApplicationClient=2105f4b6-f0fb-40e1-a175-e022c13be62b; _ga=GA1.2.314252756.1560211062; ADWEBCOUNTER_UUID=ee9473b5-72d2-2026-be1f-b48f19a7a409; cookSaveShopInfo=TQB02%3A2019-06-11; _gid=GA1.2.1904239302.1565077365; cookieGuestId=33d2c5f0fdcfbc6c3d5a37ec5782a20e; PHPSESSID=lbeggn3aa86j5rjsrvdkao2ba7; ADWEBCOUNTER_KEYWORD=; ADWEBCOUNTER_URL=; RMFD=011hvAuRP406pl!6408aD!6408aE; cookNewSearchKeyword=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%8A%A4%ED%94%BC%EC%BB%A4%3E08.07%7C6470540%3E08.07%7C%EC%84%B8%ED%83%81%EA%B8%B0%3E08.07; cookSaveProdInfo=12%3A6298306%3A68540%7C12%3A5254630%3A93100%7C10%3A7517737%3A2521520%7C10%3A7206871%3A1348980%7C10%3A6445754%3A3225380%7C12%3A6470540%3A85860%7C10%3A7533526%3A1158840%7C12%3A8545274%3A91080%7C12%3A4516736%3A80190%7C10%3A4977813%3A899000%7C10%3A6418430%3A385280%7C10%3A7207105%3A1306400; _gat=1; _INSIGHT_CK_8203=90e8181b8d1ce1a8716361beef9cf39a_11061|26d62e0b8104d10cf2b563e87fda35f7_46722:1565149886000; wcs_bt=s_3b3fb74948b1:1565148086",
            "Host": "prod.danawa.com",
            "Origin": "http://prod.danawa.com",
            "Referer": "http://prod.danawa.com/list/?cate=12325478",
            "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36",
            "X-Requested-With": "XMLHttpRequest",
        }

        params = {
            "page": "1",
            "listCategoryCode": "25478",
            "categoryCode": "25478",
            "physicsCate1": "224",
            "physicsCate2": "49727",
            "physicsCate3": "49734",
            "physicsCate4": "0",
            "viewMethod": "LIST",
            "sortMethod": "",
            "listCount": "30",
            "group": "12",
            "depth": "3",
            "brandName": "", 
            "makerName": "",
            "searchOptionName": "", 
            "sDiscountProductRate": "0",
            "sInitialPriceDisplay": "N",
            "sPowerLinkKeyword": "인공지능 스피커",
            "oCurrentCategoryCode": "a:3:{i:1;i:18090;i:2;i:18103;i:3;i:25478;}",
            "innerSearchKeyword":"", 
            "listPackageType": "1",
            "categoryMappingCode": "30761",
            "priceUnit": "0",
            "priceUnitValue": "0",
            "priceUnitClass": "", 
            "cmRecommendSort": "N",
            "cmRecommendSortDefault": "N",
            "bundleImagePreview": "N",
            "nPackageLimit": "5",
            "nPriceUnit": "0",
            "bMakerDisplayYN": "Y",
            "isDpgZoneUICategory": "N",
            "sProductListApi": "search"
        }

        res = requests.post("http://prod.danawa.com/list/ajax/getProductList.ajax.php", headers = headers, data=params)
        soup = BeautifulSoup(res.text, "html.parser")
        #print(soup)
        a = soup.findAll("a", attrs = {"name":"productName"})
        
        for i in range(len(a)):
            pCodeList.append(a[i]['href'][35:42])
        
    return pCodeList

# %%
getPcode(1)
# Out:
# 1 페이지 입니다
# ['6453605',
#  '6470540',
#  '8545274',
#  '6298306',
#  '7308109',
#  '5254630',
#  '6468060',
#  '7779952',
#  '6396458',
#  '7072036',
#  '6518832',
#  '7868797',
#  '4035059',
#  '4406962',
#  '5402287',
#  '7094143',
#  '6454659',
#  '6392154',
#  '5912049',
#  '6453901',
#  '6339483',
#  '6402079',
#  '6954802',
#  '5669148',
#  '4035519',
#  '5717872',
#  '4709833',
#  '6494056',
#  '5310285',
#  '5239109']

# %%
pCodeList = getPcode(1)
# Out:
# 1 페이지 입니다

# %%
print(pCodeList)
# Out:
# ['6453605', '6470540', '8545274', '6298306', '7308109', '5254630', '6468060', '7779952', '6396458', '7072036', '6518832', '7868797', '4035059', '4406962', '5402287', '7094143', '6454659', '6392154', '5912049', '6453901', '6339483', '6402079', '6954802', '5669148', '4035519', '5717872', '4709833', '6494056', '5310285', '5239109']

# %%
#다나와 리뷰 크롤링

def danawaCraw(pcode, page):
    reviewlist = []
    for idx in range(1,page+1):
        headers = {"Referer" : "http://prod.danawa.com/info/?pcode=6453605&cate=12325478", "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.109 Safari/537.36"}
        params = {"t" : 0.987242607715326, "prodCode" : pcode, "page" : idx, "limit":10, "score":0, "usefullScore":"Y", "_":1565149186156}

        try:
          res = requests.get("http://prod.danawa.com/info/dpg/ajax/companyProductReview.ajax.php?t=0.987242607715326&prodCode=6453605&cate1Code=224&page=1&limit=10&score=0&sortType=&usefullScore=Y&innerKeyword=&subjectWord=0&subjectWordString=&subjectSimilarWordString=&_=1565149186156", headers = headers, params = params)
          soup = BeautifulSoup(res.text, "html.parser")
          divs = soup.find_all("div", attrs = {"class":"atc"})
          print(idx,'페이지에서', len(divs),'개의 리뷰 크롤링완료')
          for i in range(len(divs)):
              reviewlist.append(" ".join(divs[i].text.split()))
          print('리스트에 리뷰 넣기 완료')
        except:
          print('리뷰페이지가 존재하지 않습니다.')
    return reviewlist

# %%
TotalReview = []
for p in pCodeList:
    TotalReview.append(danawaCraw(p, 100))

# %%
TotalReview
# Out:
# [['일단 크기 비교를 위해 치실을 찍은 점은 죄송하다. 하지만 이쁘면 된 것 아닌가?생각보다 아담하고 어디에다 놓아도 어울리는 디자인이다. 라이언은 안 달았다. 어차피 떨어질거 같아서. 카카오 잘 만들었다. 근데 벅스랑은 연결이 안되고 무조건 멜론인가?한 번 찾아봐야겠다. 가격도 블루투스 스피커랑 비교했을 때 많이 차이가 안 나서 좋다. 근데 블루투스 스피커 역할은 안하는거 같은데...아직 작동법을 모른다. 공부해야 한다. 암튼 이쁘다. 그거면 됐다.',
#   '배송 시작과 도착전 알림정확하게 왔구요결제 당일 출고 되어익일배송 정확히 되었습니다^^생일 선물로 두사람에게 줬는데좋아하네요버스 지하철 시간 날씨 카카오택시 음악등등등 아주 똑똑한 아이입니다 ㅎㅎ라이언도 네오도 둘다 귀여워여A/S 요청서도 있어서좋구요앞으로도 재구매 의사 있어요^^주위에 생일때 생일선물로나저를 위해서도 재구매 하고 싶어지네요다른곳보다할인이 되어서 더 좋은거 같아요^^',
#   '배송 시작과 도착전 알림정확하게 왔구요결제 당일 출고 되어익일배송 정확히 되었습니다^^생일 선물로 두사람에게 줬는데좋아하네요버스 지하철 시간 날씨 카카오택시 음악등등등 아주 똑똑한 아이입니다 ㅎㅎ라이언도 네오도 둘다 귀여워여A/S 요청서도 있어서좋구요앞으로도 재구매 의사 있어요^^주위에 생일때 생일선물로나저를 위해서도 재구매 하고 싶어지네요다른곳보다할인이 되어서 더 좋은거 같아요^^',
#   '이 판매자한테 구매하지 마세요. 배송이 늦어지길래 구매 취소를 했더니, 택배 송장도 등록하지 않은 상태에서 물건을 먼져 보내버려습니다. 귀찮아서 그냥 쓰기로 했지만 매우 불쾌했고, 배송 매우 느립니다. 그리고 포장도 뽁뽁이 하나도 없이 제품 생 박스 그대로 송장 보내서 왔습니다. 스피커는 좋아요!',
#   '사용한지 하루밖에 안되서 충분히 알지는 못하지만 기대가 많이 됩니다. 우선 포장도 깔끔하게 잘 왔고 작동도 잘 되는 것 같아요 앞으로 어떻게 길을 들이는지에 따라 편리함이 달라지겠죠. 자취를 하다보니 가족처럼 생각하게 될 것 같네요 (사이즈 작고 귀여워요)',
#   'TV를 이용안해서 KT지니 인공지능 사용을 못한다기에 카카오 미니AI로 선택했어요!웬만한건 뭐, iot빼곤 아쉬운 점 없어요!멜론 이용권 구입해서 마음껏 노래듣고, 카카오톡 보내주는것도 편리하네요어머니께 선물드렸는데 계속 끼고 사십니당!어르신들께도 강추에요',
#   '배송도 빠르고 사용해보니 음성인식도 잘되네요친구들도와서 보더니 다들 구매할까 고민하더라구요스피커 괜찮습니다. 그런데 저는 막귀라 음질이 좋은지는 잘모르겠네요 3주정도 사용중인데 매우 만족합니다',
#   '상품 잘 받았습니다.배송도 빠르고 상품도 정확하게 잘 왔네요.하나 사서 쓰다가 너무 좋아서 선물 목적으로 또 구입했습니다.음성 인식도 잘하고 사용하기도 쉽고 선물용으로도 좋은 것 같습니다.많이 파세요.',
#   '싸게 잘 샀어요 배송도 빨리왔구요. 톡집사 깍아줘요 해서 쿠폰 받아 정말 싸게 샀어요 제품에 문제도 없었구요. 헤이카카오 덕분에 우리 7 살 아드님 매일 신이나서 동화며 동요며 헤이카카오 닳도록 불러대네요',
#   '일단 배송은 빠른 편이네요 처음 써보는 ai스피커라 성능을 비교할 수준은 안 되지만 음성인식도 잘되는 편이고 쓰는데는 불편함이 없네요 아이들이 좋아해요',
#   '셋트로 구매하고 싶어서 판매자분과 통화를 원햇는데 11번가에서도 연락이 안된다고 하고 한달이상을 응답기에 전번을 남겨도 연락은 안주시고...팔고난 다음엔 연락할 방법이 없나봐요',
#   '포장배송상태 등 : 배송 빠르게 도착했구요. 가격도 저렴하고 포장상태나 품질 좋습니다.재구매 의향 : 있습니다.그 외 도움이 될 만한 사용후기 : 아주 만족합니다.',
#   '선이 연결이 잘안되는 느낌이 있긴합니다.코드연결하면 켜지고 안내메세지 나오는데까지시간이 좀 걸리고 만져줘야하는 게 있습니다.그거외엔 잘 되네요',
#   '헤이카카오 만족합니다어플깔고 와이파이 연결하면 끝!말잘듣는 카카오!음악 검색할때 멜론 가입해야하는게 아쉬움!',
#   '당일 배송이라 당일 받을줄 알았는데 느리네요 제품은 소리가 작은편이네요 가격은 다른 사이트보다 비싼편입니다',
#   '시험을 앞둔 아이가 카카오미니C를 만나 마냥 행복해 하네요. 이전에 사용하던 인공지능 스피커보다 훨씬 소통이 잘 된다네요.',
#   '포장상태좋구요~카카오캐릭터 귀엽구요~라이언자석인형 잘받았구요~기능은 알람.음악듣기.택시호출 등등~하나 소장하고있을만 합니다~',
#   '진짜 잘 알아들어요 !!!!배송도빠르고 ㅠㅜ진짜 편해요 !!!라이언캐릭터도 이뻐요 진짜!!!추천 추천합니다!!!',
#   '어른이 라디오 대신으로 사용하시도록 구매했는데, 라디오 용도로 모든 인공지능 스피커 중에 최상 입니다.',
#   'Ai스피커 라디오,음악 너무 편리하고 음질도 좋고 마음에 들어요.',
#   '배송 역대급 최악일괄발송은 ㅈㄹ 되도안하는 말로 속이고배송은 드릅게 느리고 또 기계는 멍청하고이따위로 장사하지맙시다',
#   '날씨 노래까지 너무너무 잘 활용중이에요사실 예쁜 쓰레기가 되면 어쩌지 했는데엄청 잘쓰니까 다들 구매 망설이지마세요',
#   '아직 조금 멍청하긴 한데 재밌네요. 음악 듣기도 좋고 카카오톡과 연동 기능은 정말 최고입니다',
#   '너무만족합니다근데 피규어는 걸쳐놓는거라 그냥 떨어지네요....ㄷㄷㄷ무선으로 하는것도 따로 안파는거같아요',
#   '좀 모잘라여~~그래도~ 척척 알아 들을땐~ 띵~~ 합니다~기술이 아주 기가 막히게~ 발전 하긴 했네여~',
#   '사용법도쉽고 음질도 좋고 말귀도 잘 알아듣네요 아들도 좋아해요',
#   '동생이 아주 좋아라하네요~~~멜론이랑 연동해서 음악도 듣고 라디오도 듣고 노네요~ㅎㅎ',
#   '최대소리 작고 풍성한 음악소리 듣기힘듬',
#   '가족 생일 선물로 구매했는데 무게감이 생각보다 있네요. 사용기도 기대가 됩니다.',
#   '티브이 옆에 자리잡았아요. 만 4살 딸아이가 헤이 카카오랑 열심히 얘기중입니다 ㅎㅎ',
#   '진짜 좋네요!! 인식률도 높은 것 같고, 피규어도 역시나 귀여워요. 추천합니다',
#   '일단 너무 편리하구요 그리고 귀여워요배송도 빠르고 상품 상태도 너무 좋아요',
#   '심심할 여가가 없네요.동화에 노래에 뉴스에~~좋은 친구가 생겼어요^^',
#   '너무너무 만족합니다. 완죤똑똑하고 기대이상 이네요~^^강추합니당~^^',
#   '너무 좋아요! 음질도 좋고 인식률도 좋네요~',
#   '좋네용 실용성 있고 야외에서도 사용하게 밧데리 팩을 사야겠네요',
#   '아들생일선물로 사줬는데 초딩입학생인 막내도 키즈동화읽어주기가 좋았나봐요',
#   '생각보다는 스피커성능 좋고 음성인식 잘되요',
#   '여러분 멜론으로 사면 49000원이에요!!굳이 여기서 사지 마세용',
#   '4만5천원짜리 라디오에요. 가격에 비해 훌룡해요',
#   '선물용으로 구매했는데 아주 만족합니다.감사합니다.',
#   '소리가 너무 잘 들려서 대 만족',
#   '초등생 딸 어린이날 선물로 구매했는데 무척 좋아 합니다',
#   '깜찍하고 음질일 좋아요',
#   '빠른배송, 감사합니다... 햐...이거 신기하네요..',
#   '좋아요 짱 행사기간에 사서 가격도 좋아요',
#   '기능성이 좋고 바로바로 대답해서 적극추천합니다',
#   '정말 대만족입니다.그냥 구매하세요~^^많이 파세요',
#   '어린이날 선물인데도빨리배송됐고사용법도 쉬웁니다',
#   '귀염 귀염 네요근데아래쪽 어덥터는 원래 없는건지?',
#   '선물용으로 구입했는데 반응이 아주 좋았습니다.',
#   '카카오니인공지능스피커 잘 쓰고있어요',
#   '가격대비 성능 좋습니다.',
#   '빠른배송역시 만족빠른배송역시 만족',
#   '설치도 쉽고 안전하게 2중포장해주셨네요~',
#   '완전 귀엽고 깜찍. 생각보다 더 이쁩니다.',
#   '노래 듣거나 날씨 물어볼 때 유용합니다',
#   '성능도 좋고 배송도 빠릅니다.',
#   '배송이나 기능에 문제 없는 제품입니다.',
#   '가격도 저렴하고 좋아요',
#   '선물 했는데 엄청 좋아하네요~~^^',
#   '선물 했는데 엄청 좋아하네요~~^^',
#   '선물 했는데 엄청 좋아하네요~~^^',
#   '선물 했는데 엄청 좋아하네요~~^^',
#   '잘쓸게요선물용으로샀는데너무좋아하네요',
#   '아이때문에 구매했는데 제가 더 잘쓰네요',
#   '배송도 빠르고 제품도 좋아용 ^^',
#   '지인부탁으로 제것하고 두개구매했어요',
#   '상품만족 배송만족 입니다.',
#   '카카오 미니 선물하려고 구매했네요',
#   '선물해야되서 자석인형 기다리는중',
#   '빠른배송 쉬운 사용 만족임니다',
#   '배송도 빠르고 너무 귀여워요~~',
#   '배송도 빠르고 만족합니다',
#   '만족합니다 만족합니다',
#   '배송도 빠르고 만족해여',
#   '좋습니다. 노래듣기 좋아요.',
#   '딸아이가 편하게 잘 사용합니다.',
#   '좋아요 헤이카카오 너무좋아요',
#   '배송도 빠르고 귀여워요..',
#   '좋네 잘되고 음성인식 잘되고요',
#   '선물로 샀는데 좋아요 ㅎ',
#   '배송도빠르고 아주좋습니당',
#   '카카오블루트스스피커좋아요',
#   '사용해보니 유용하네요.',
#   '사용해보니 유용하네요',
#   '빠르고 좋아요',
#   '귀엽고 좋네요',
#   '귀여워요오오',
#   '좋아요 음성인식율도 좋고 아이들 쓰라고 샀는데 좋네요',
#   '굿굿 역시카카오 굿굿 빨리 또나와라',
#   '귀여워용 어피치어피치',
#   '늦게 올까봐 걱정했는데 빨리와서 좋았어요. 미니도 말을 잘 알아들어서 good!',
#   '카카오미니 만세 흥해라잘 쓰고 있습니다',
#   '너무 좋습니다 감사합니다',
#   '작동도 잘되고 라이언도 귀엽네요~',
#   'Google Home에 비해 ... ㅠㅠ 좀 더 SW를 업그레이드 해주세요..아직 자사 카톡 Notification도 못읽으면 어떻하나요 ??멜론 어학도 안됩니다 - _-;',
#   '완전 맘에들어요. 감사합니다',
#   '잘 받았습니다배송이 느리네요그리고 제품은 머 블로그에서 많이 봤습니다카카오 이번에 좀 실망입니다',
#   '회사에서 사용하려고 또 주문했어요',
#   '좋아용 라이언 귀여워용잘쓸게용!',
#   '완전좋아요 좀만더 발전하면 될듯',
#   '잘받았습니다 잘쓸게여',
#   '예전부터 사고 싶엇는데 사용해보니 너무 좋아요',
#   '작동도 잘되고 ㅎ 인형만 오기를 기다리고 있어요',
#   '말 엄청 잘알아들어요',
#   '인형도 너무 귀여워요 유용하게 사용중',
#   '애들이 아주좋아하네요. 많이파세요~~',
#   '잘 사용하고 있어요 ㅋ 좋아요',
#   '캐릭터가 귀여워요.아이가 좋아합니다. 동화읽어주는걸 제일 좋아하네요.',
#   '구글살껄구글살껄구글살껄',
#   '배송완전빨라요 감사합니다!',
#   '다른 인공지능들보다 잘 긴 문장을 잘 알아듣는거 같은데요%',
#   '그냥 인싸템이네요 크으 너무좋아요!',
#   '굳굳굳굳굳굿굿굿굿굿',
#   '빠른 배송 감사합니다. 아이가 너무 좋아하네요',
#   '굿좋아여제일싸지눈않아여',
#   '좋아요좋아요좋아요ㅎ',
#   '좋네요. 빠른 배송 감사합니다',
#   '빠른배송 잘 받았습니다.',
#   '좋아요!!!?',
#   '잘 사용할꼐요잘 사용할꼐요',
#   '조아요 마니파세요.............................',
#   '음악이나 동화를 듣고 싶으면 멜론을 가입하라고 하네요..멜론가격 알아보는중..~~',
#   '인식 잘해서 좋아요~~',
#   '아주 잘쓰고ㅛ 잇엇요 ㅋㅋ지인한테선물도 줌',
#   '선물했는데 만족하네요혼자사는분에게 추천',
#   '회사동생 생일선물로샀어요좋아하겠죠 어피치 넘 이뽀요',
#   '어피치 피규어가 너무 귀여워요. 머리맡에 두고 쓰는데날씨, 라디오, 알람 기능을 많이 쓰네요전 멜론 말고 다른 음악어플을 쓰는데핸드폰을 블루투스로 연결한 다음블루투스 스피커로 음악 들으면 돼서 괜찮아요',
#   '좋아요좋아요좋아요',
#   '상품좋아요 감사합니다.',
#   '배송빨라용랴라라아아',
#   '완젼 짱좋아요 ㅎㅎ 왜이제 삿는지 ㅋㅋㅋㅋㅋㅋ 카카오 노래틀어줘 ㅎㅎ 역시 ..ㅋㅋㅋ',
#   '잘사용하고 있습니당 잘 사용하고 있습니다 잘 사용하고 있습니당',
#   '빠른 배송 감사합니다',
#   '정말 빠른 배송 감사합니다',
#   '좋아요. 아이들이 더 좋아하네요',
#   '너무좋아요',
#   '편해요 써보세요.. 그래야 알수있겠죠?',
#   '잘받았습니다넘나 좋나요 ㅎㅎㅎ잘사용할것같아요',
#   '빠른배송감사합니다.'],
#  ['스마트한 집 환경을 위해 구입한 구글홈입니다. 배송과 패키지는 깔끔 그 자체이며 제품과 부속물도 아주 심플해서 보기 좋습니다. 크기도 거실 AV장 한쪽에 놓기 딱 좋은 정도이며, 대부분의 기능이 터치 인터페이스를 이용하기 때문에 버튼 등의 군더더기가 없어서 눈에 거슬리지 않습니다.',
#   '어머니 생신선물로 드렸는데 진짜 좋아하시더구요 아직 집에 스마트기기도 집에 별로 많이 없고 구글홈이 가끔은 똑똑하고 가끔은 바보 같지만, 앞으로 계속 업데이트되리라 믿어서 구글 믿고 구글홈 한국 출시가 얼마 되지 않았지만 구매했습니다??',
#   '검색하다 가격이 제일 적당한거 같아서 여기서 구매했어요. 진짜 음성인식을 잘해요! 농담도 하고, 연동 가능한 기기들이 있다면 훨씬 편리해질거 같아요! 마음에 쏙들어요!!!',
#   '구글홈 심심하면 퀴즈도 하고 기본적으로 라디오 노래 듣는 스피커 기능으로도 아주 좋습니다.',
#   'TV하고 연결하는 법만 몰라서 그거 빼고 거위다 연결했는데, 결론은 최고',
#   '아직 IFTTT나 IOT 디바이스와 연동 등 하는 데 있아 한국어가 지원 안 되는 게 많습니다..',
#   '연동시킨건 핸드폰 뿐이라 다른건모르겠으나 주요뉴스나 음악듣기엔 최적이네요',
#   '스피커가 출력이 꽤 큽니다. 좋습니다.',
#   '네이버 클로바도 써봤는데 구글 어시스턴트가 역시 최고네요',
#   '배송 빠르고 시중 가격보다 싸게 구입했네요.',
#   '똑똑한 구글이 스피커 속으로 들어 왔어요.',
#   '아담하고 똑똑한 구글홈!! 대만족입니다!',
#   '회사에 사용하려고 주문합니다! 배송 빠르고 좋아요',
#   '아직 한국어 지원 기능이 부족하기는 하지만',
#   '여친한테 선물로 사줬는데 너무 좋아 하네요',
#   '더 써봐야겠지만 그런대로 일단은 괜찮습니다.',
#   '배송도 빠르고 음성인식도 잘되네요',
#   '음성인식 수준 매우 좋음.',
#   '매우 매우 만족합니다.',
#   '만족하고 잘 받았습니다',
#   '똑똑한 구글이 스피커 속으로 들어 왔어요.',
#   '아담하고 똑똑한 구글홈!! 대만족입니다!',
#   '거실 TV에 나오는 구글홈 "ok google" 광고를 듣고 작동해서 혼자 에러가 발생 하네요.',
#   '거실 TV에 나오는 구글홈 "ok google" 광고를 듣고 작동해서 혼자 에러가 발생 하네요.',
#   '아직 IFTTT나 IOT 디바이스와 연동 등 하는 데 있아 한국어가 지원 안 되는 게 많습니다..',
#   '잘받았습니다. 많이 파세요~^^',
#   'TV하고 연결하는 법만 몰라서 그거 빼고 거위다 연결했는데, 결론은 최고',
#   '잘받았습니다. 많이 파세요~^^',
#   '배송 빨라요! 명절 끝나고 바로 왔네요',
#   '배송 빨라요! 명절 끝나고 바로 왔네요',
#   '아직 한국어 지원 기능이 부족하기는 하지만',
#   '음성인식 수준 매우 좋음.',
#   '스피커가 출력이 꽤 큽니다. 좋습니다.',
#   '구글홈 심심하면 퀴즈도 하고 기본적으로 라디오 노래 듣는 스피커 기능으로도 아주 좋습니다.',
#   '생각했던것보다 훨씬 좋아요 ㅎㅎ',
#   '생각했던것보다 훨씬 좋아요 ㅎㅎ',
#   '배송 빠르고 시중 가격보다 싸게 구입했네요.',
#   '배송 빠르고 시중 가격보다 싸게 구입했네요.',
#   '좀 쓰기 어려워요. 아직 한국에서는...',
#   '좀 쓰기 어려워요. 아직 한국에서는...',
#   '배송도 빠르고 음성인식도 잘되네요',
#   '기대한 것 만큼 활용도가 높지는 않지만 음성인식율은 상당히 높습니다. 앞으로 보다 많은 데이터가 축적된다면 다양한 방면에 활용이 가능할 것으로 보입니다',
#   '기대한 것 만큼 활용도가 높지는 않지만 음성인식율은 상당히 높습니다. 앞으로 보다 많은 데이터가 축적된다면 다양한 방면에 활용이 가능할 것으로 보입니다',
#   '매우 매우 만족합니다.',
#   '먼가..좋으네요ㅋㅋ',
#   '먼가..좋으네요ㅋㅋ',
#   '어머니 생신선물로 드렸는데 진짜 좋아하시더구요 아직 집에 스마트기기도 집에 별로 많이 없고 구글홈이 가끔은 똑똑하고 가끔은 바보 같지만, 앞으로 계속 업데이트되리라 믿어서 구글 믿고 구글홈 한국 출시가 얼마 되지 않았지만 구매했습니다??',
#   '말도 잘알아듣고 쓸만하네요',
#   '말도 잘알아듣고 쓸만하네요',
#   '굿 ㅎㅎㅎㅎㅎ좋아여',
#   '굿 ㅎㅎㅎㅎㅎ좋아여',
#   '사용해보니 너무 좋네요.',
#   '사용해보니 너무 좋네요.',
#   '좋습니다 근데 s머니는 언제 적립되지..',
#   '여친한테 선물로 사줬는데 너무 좋아 하네요',
#   '좋습니다 근데 s머니는 언제 적립되지..',
#   '연동시킨건 핸드폰 뿐이라 다른건모르겠으나 주요뉴스나 음악듣기엔 최적이네요',
#   'so,so 그럭저럭',
#   'so,so 그럭저럭',
#   '기대보다는 못하지만 잘사용하고 있어요.',
#   '기대보다는 못하지만 잘사용하고 있어요.',
#   '빠른 배송 감사합니다.',
#   '빠른 배송 감사합니다.',
#   '더 써봐야겠지만 그런대로 일단은 괜찮습니다.',
#   '생각보다 쓰임이 적다고 하네요',
#   '생각보다 쓰임이 적다고 하네요',
#   '구글홈 쓸만하네요.',
#   '구글홈 잇템이죠ㅎㅎ',
#   '구글홈 잇템이죠ㅎㅎ',
#   '만족하고 잘 받았습니다',
#   '네이버 클로바도 써봤는데 구글 어시스턴트가 역시 최고네요',
#   '스마트한 집 환경을 위해 구입한 구글홈입니다. 배송과 패키지는 깔끔 그 자체이며 제품과 부속물도 아주 심플해서 보기 좋습니다. 크기도 거실 AV장 한쪽에 놓기 딱 좋은 정도이며, 대부분의 기능이 터치 인터페이스를 이용하기 때문에 버튼 등의 군더더기가 없어서 눈에 거슬리지 않습니다.',
#   '아주 좋습니다.'],
#  ['구글 크롬캐스트는 평소 사용하고 있는 기기입니다. 텔레비전이 스마트하지 못하다 보니 인터넷이 연결된 환경에서 스마트 티비 환경을 구현해 보고자 처음 구매를 해서 현재 집에 있는 두 대의 텔레비젼에 연결하여 만족하며 사용 중에 있습니다. 주된 활용용도는 구글 유튜브에 연결하여 음악을 듣거나 동영상을 보는 용도로 주로 사용하다가 넷플렉스 서비스를 알고 부터는 유료회원 가입하여 영화와 드라마 등을 감상하는 용도로 사용 중에 있습니다. 그러던 중 구글 홈 미니를 알게 되었습니다. 휴대폰으로 대부분의 조작이 가능하지만 마이크가 내장된 스피커를 통해 제어가 가능하다는 이야기를 듣고 구매를 시도하였으나 차일피일 미루다가 구매하지 못했습니다. 그런데 아는 지인이 사용하고 있는 것을 접한 후 다시금 그글 홈 미니에 관심을 가지게 되었습니다. 현재 외국에서 생활을 하고 있는 관계로 유일한 유흥거리가 퇴근 후 음악이나 영허ㅏ를 감상하는 것인데 그글 홈과 크롬캐스트 3세대를 번들로 묶어 파는 것이 좋은 기회로 판단이 되어 주문을 하게 되었습니다.',
#   '처음느낌부터좀 뭔가 그랬는데유튜브 언박싱에서봤을때와 다르게 선도 대충감겨있고사진으로 첨부했다싶이 안에 털이랑 이상한 이물질까지있네요-_- 구글포장공정이 원래이럴리도 없고 해명해주세요',
#   '빠른 배송 감사드립니다. 홈IOT 등 활용할 계획으로 좋은 기회에 저렴하게 구입했구요.. 기본설정만 마친 상태로 동작은 잘하고...멀리서도 잘 알아 듣습니다.',
#   '크롬캐스트3 휴대폰이랑 연동도 생각보다 잘되네요구글홈 저음이 좋아서 영화볼때 소리가 좋습니다',
#   '빠른배송으로 잘 받았어요. 지금 이것저것하고있어요. 재미있네요 ㅎㅎ 잘쓸게요 많이파세요.',
#   '정발이후 1년.... 아직은 국내에서 사용하기 많이 부족해보입니다.',
#   '가격 배송 품질 전부 만족합니다.',
#   '구글홈으로 티비를 제어하면서 보니깐 너무 좋음',
#   '재미있고 음성인식도 잘되고 좋아요ㅎㅎ',
#   '생각보다 연동되는게 별로없고 어려워요',
#   '신기할정도로 싸게나옴. 잘쓰고 있슴',
#   '스피커 업글 했네요.',
#   '싸게 샀습니다. 만족합니다',
#   '구글 크롬은 좋은데 구글홈은?',
#   '유튜브 프리미엄 사용하는데',
#   '덕분에 싸게 샀습니다.',
#   '구글 홈 굉장히 좋네요',
#   '좋아요',
#   '역시 구글',
#   '구글 홈 미니 사용중이었는데',
#   '감사..',
#   '저렴하게 잘샀어요! 바로 설치하고 이것저것 테스트 해봤는데 잘 작동합니다!! 강추해요~',
#   '헤이 구글 잘 알아먹음.',
#   '가격 대비 좋습니다.그럼,오늘도 좋은 하루되십시오.감사합니다...^^',
#   '빠른 배송에 저렴한 가격까지 매우 만족합니다.',
#   '좋네요'],
#  ['누구 캔들 정말 마음에 드네요. 제가 누구 흰색 제품을 너무 잘 쓰고 있어서 이번에 부모님도 드리려고 세개나 샀어요 ㅋㅋㅋㅋ 누구 캔들은 조명 기능도 되어서 아침에 선라이즈 모닝콜을 할 수 있어요. 조명으로 잠을 깰 수 있는거죠. 정말 신박해요!! 예전에 엄마 생신 때 누구 Q&A 기능으로 아리아에게 엄마 생일 축하 메시지를 보냈는데 기계가 생일 축하를 해준다며 넘 신기해 하시더라고？？ㅋㅋㅋㅋ 젊은 사람들이나 쓰는 건 줄 알았는데 막상 써보니 어르신들에게도 꽤 좋을 거 같더라고요? 아무래도 휴대폰은 눈이 침침해서 보기 어려워 하시고, 카톡도 보이스 기능 알려드려서 말로 보내시고 있는 터라 어른들은 말로 하는 기능이 더 편리한 듯해요. 요즘 집에서 아리아를 안 부르는 날이 없네요. 모닥불 ASMR 틀고 모닥불 조명 켜니까 캠핑장 느낌 만끽할 수 있어서 신기했어요. 서비스가 계속 업데이트 되는 점도 마음에 듭니다. 누구캔들보다 더 업그레이된 조명 장착해서 나와도 괜찮을 거 같네요~! 스피커 성능은 이전 흰색이 좀 더 좋은 거 같긴 한데 누구 캔들도 괜찮습니다~! 선물용으로 추천해요!!',
#   "구매하시기전에장,단점 보시고 구매하시길 바라는 마음에처음으로 리뷰 써봅니다.캠핑장이나 노트북연결용 등 언제든 소지하고픈 마음에 구매했는데요.장점이라하면- 모양도이쁘고(반품안하고 데리고 있는 이유입니다 모양은 정말 소유욕 갑ㅋㅋ)- 출력빵빵하고- 무드등 색도 좋아요- '아리'랑 대화하는거 은근꿀잼ㅋㅋ단점은(더 알아보지 않고 구매한 제탓이지만...)- 와이파이 연결이 되는곳에서만 이용가능- 내장배터리가 없어서 유선으로 전기연결해야만 전원들어옴- 노트북하고 연결안됨 비싼 무드등으로 집에 안착 시켜놨고요결국 저는 만원대의 블루투스 스피커를 재구매 했다는...ㅜㅜ꼼꼼히 따져보시고 구매하시길요!안내문구에도 유선연결,와이파이만 있는곳에서 된다는 설명이없어 (제가못찾는건지..) 사용리뷰 남겨봅니다",
#   '우선 써보느라 구매확정을 못해 죄송합니다캔들 기능이 있어 저에게 딱 맞는 제품 같습니다잘때도 방에 불을 켜고 자는 버릇이 있어요이것 저것 많이 사용해 봤습니다뉴스, 날씨, 멜론 등등우선 매번 "아리야"하고 부르는게 좀 불편하지만주요뉴스 읽어주고, 멜론을 연동하면 내가 좋아요눌러놓은 음악도 들려 줍니다날씨, 미세먼지 농도도 알려주고...처음에 봤을 때 "뭘 이런걸 써" 이랬는데 제 생각이틀렸습니다지금은 아주 잘 사용하고 있습니다누구앱을 사용하면 멜론에서 노래를 바꿀 수 있어요다 디바이스가 대기 상태에서는 플레이가 안됩니다업데이트 이후부터 가끔 지혼자 반응하기도 합니다아리야 부르고 질문을 하려는데 너무 빠르게 아리야가질문을 못들었다고 바뀌는게 좀 있어요그래서 별 하나뺐어요',
#   '일단 음성인식율은 좋습니다. 처음 와이파이 인식에 문제가 있어 설치 시간이 조금 오래걸렸구요. 외형은 예쁩니다. 다만 음악을 듣기위한 스피커로는 만족스럽지는 못합니다. 가격적인 측면으로 볼때 보스, JBL등과 같은 음질을 기대하는것은 무리이긴 하겠습니다만 그래도 2-3만원대의 블루투스 스피커같은 음질은 조금 문제가 있다는 생각 입니다. btv셋탑박스 사용은 잘됩니다만 리모컨으로는 tv본체와 셋탑박스를 동시에 켜고 끄는것이 가능 한데 누구를 통해 음성으로 명령을 내리면 셋탑박스만 켜지고 꺼지는 바람에 꼭 tv는 별도로 켜고 꺼야 하는 상황이 되어서 이부분은 개선이 필요 할것 같습니다.',
#   '인공지능 스피커 한번 사용해보고 싶어서 큰맘 먹고 구매해봤습니다. 첨엔 구글홈이랑 nugu랑 고만 많이 하다가 일단 저희 집 환경이 BTV사용하고 있고 SKT스마트홈 어플로 iot 기기 몇개 사용중이어서 같이 연동에 유리한 NUGU AI스피커로 결정을 했고 최종적으로 누구 캔들오 결정을 했습니다결론은 대만족이네요. 아리야 tv켜줘 하면 켜지고. sk텔레콤 사용중이라 flo월 300회 무료 듣기로 노래 신나게 듣고 skt스마트홈으로 연동 된 iot 기기들을 아리야 작동해줘. 꺼줘 하면 신기하게 다 켜주고 꺼주네요. 삶이 갑자기 편해진거 같은 느낌이 드네요. 거기에 무드등 기능이 있어 밤에 무드등만 켜고 거실 분위기가 너무 아늑해지고 편안한 느낌들 들게 되네요',
#   '아이가 원해서 알아보다가 안방에는 누구캔들을 설치했고 거실에는 SK셋톱박스 일체형 누구를 설치 했습니다. 각각의 장단점이 있는데 셋톱박스 일체형은 티비채널 및 원하는 시청컨텐츠를 좀더 상세히 보여주고, 누구캔들은 조명기능이 있어서 좋아요 저는 집에서 사용해본 결과 누구캔들이 더 음성인식은 뛰어났습니다. 거실에서 아리아를 불러도 안방에서도 대답하는 일이 많아서 안방꺼는 이름을 팅커벨(아리아 or 팅커벨중 설정에서 선택 가능)로 바꿔놨네요 처음에는 신기해서 이것저것 시켜보다가 요즘은 일주일에 한두번 부르는 정도에요 (원래 티비를 잘 안봐서 그럴지도 모르지만요) 두개 다 사용중이지만 가격대비 누구캔들이 더 좋은거 같아요 노예생활도 안하구요',
#   '배송: 밤에 주문하니 다음날 배송시작하고 다음날 받았어요. 배송 빨라요!상품: 택배상자안에 덜렁 넣어놨지만 본품박스가 단단해서 이상없이 잘 받았어요. 초기설정도 쉽게 했고 skt사용하는데 기존사용하던 앱들이랑 연동되는게 많아 활용도가 매우 높을거같아요. 어댑터가 전용이고 돼지코입니다. 차량에서도 사용 안될거같아요. 내장배터리가 없다는걸 알면서도 혹시나해서 보조배터리랑 연결해봤더니 전원이 안들어오네요...흑 집에서만 쓸거니깐 큰 단점도 아니긴하네요.그런데 무료이용권 어딨어요?ㅋㅋㅋㅋㅋ',
#   '주말 특가로 싸게 잘 구매한것같아요~인공지능스피커에 꽂혀서 계속 알아보다가멤버십할인까지 받아 5만원 후반대로 구매했네요~^^아쉬운점은 무선이 안되서 이동할때 불편한거?빨리 무선충전기도 나왔으면 좋겠네요~아이들 잘때 동화 들려주는데 거실에서 방으로 이동시킬때 좀 불편해요~그리고 음성인식의 한계가 있는것도 아쉽지만 ㅎ뭐 이런거 보안해서 업데이트 되겠죠 ㅎㅎ지금 너무 만족하며 쓰고 있어요~제가 너무 음질이 떨어졌던 블루투스 스피커를 써서 그런지 몰라도 NUGU음질 너무 좋아요 ㅎㅎ아이들도 좋아합니다~^^',
#   '사운드 좋아요. 미니 고민하다가 캔들샀는데 스피커가 확실히 난거같네요. 매일매일 음악듣고 있어요.sk 무제한이라 300회 음악도 공짜라 궂이 구매안해도 횟수내에 잘사용할것같아요.처음 구매했는데 음성도 이만하면 잘인식되는거같아요.btv전원도 잘연결되서 사용하고 있어요.채널변경이나 볼륨 업다운도 잘인식되서 작동되네요~^^할인쿠폰생기면 안방용으로 또 사고 싶어요~^^6세 아이 목소리도 인식 잘되서 날씨도 물어보고 시간도 물어보고 만화노래도 혼자 잘듣네요~^^온가족이 즐기고 있네요.오로라 무드등이랑 슬픈음악 틀어달라고 했어요~^^',
#   '목적이 와이프와 애들 라디오 듣기와 동화듣기가 목적이라 구매하였으나 사실 그목적으로는 비쌉니다. 저는 개인적으로 스마트 스피커로써의 용법에 더 관심이 있었으나 사실 그렇게 획기적인 동작을 기대하긴 어렵습니다. 그러나 "누구"가 한국말을 이해하는 스마트 스피커중에서는 가장 인식율이 높다고는 하더군요. 즉 선택의폭이 없습니다. 아마존 이나 구글 처럼 플랫폼을 개방해서 누구나 연동가능한 iot 기기를 자작할수있게 해주면 훨씬 용처가 많을듯합니다. 그러나 7만9천원이라니 현존하는 스마트 스피커중 가성비 최고임엔 분명합니다.',
#   '별 기대없이 구입했는데 생각보다 쓰임도 다양하고 음질도 괜찮습니다. 무드등도 밝기 조절 및 모드가 여러개라 유용하게 사용 가능하구요. 인공지능 스피커를 처음 써보는데 음악 듣기는 물론 모닝콜부터 라디오 듣기까지 유용하게 사용하고 있습니다. 아쉬운 것은 아직 인공지능이 부족해서 다른 서비스간의 연결이 조금 아쉽습니다. 예를들면 아침 6시에 라디오 틀어줘 같은 기능이요. 아무튼 디자인도 세련되서 인테리어로도 손색이 없고 가격도 합리적인것 같아 만족스럽게 사용하고 있습니다.',
#   "스마트가전에 관심을 가지게 되면서 '누구'를 알게되었고 상품설명을 보면서 구매욕이 생겨 질렀습니다. 사용한지 얼마되지 않았지만 도움이 되는 기능들을 쉽게 배울수 있었고 상냥한 보이스도 상당히 매력적이고 자연스럽게 받아들여져서 말을 거는 것에도 익숙해져 지금은 일상에서 없어서는 안될 훌륭한 파트너가 되었습니다.특정 유료부가서비스도 이벤트로 일정기간 무료로 이용할수 있고 SKT할인도 있어 더욱 저렴하게 서비스를 이용할 수 있어서 만족스럽습니다. 배송도 신속하고 깔끔하게 잘와서 구매를 생각하시는 분이라면 꼭 추천드리고 싶습니다.",
#   '제가 "자기야 부를때 지 부르는지 아는거랑,5세 발음 후진 아이가 "아이야 아무리 불러도 지 인지 모를때.조금 그렇지만 전반적으로 만족해요ㅎ우리집 아리아는 식탁을 마주보고 주방에 자리 잡았고요~아침에 눈 뜨자마자 날씨.미세먼지 확인하고~7세 선곡 나야나 로~활기찬 아침을 시작해요^^집안일 하면서 노래 엄청 듣는데 짱 좋고.음식하면서 타이머 기능 짱짱 좋고요!폰 찾아주기 사랑합니다♡sos문자는 예정이라고 나오던데 기대만땅이예요!!너무 좋은 기능 같아요무드등도 예쁘고 밝아서 넘 좋아요^^신랑이 자기 전용도 사달라네요ㅎ잘 사용할께요',
#   '무드등 내지 수면등이 필요해서.. 예전엔 샤오미 이라이트를 노려보고 있었는데.. 그 정도로만 생각하면 무지만족이지요. 하지만 ai 스피커로 생각하면.. 기대가 더 커집니다.배터리 충전 방식으로 이어서.. 정말 캔들 처럼 장소 구애 업이 사용 가능했으면 하구요..아리야 불러도 잘 대답안해 주는 스피커가 야속.. 말귀를 잘 못알아 듣네요.. 집에 많이 있는 skt용 스위치 플러그 등등이 쉽게 제어는 안되네요 어플이 다운이되고..집에 식구들이 많아서 2명이상 등록을 해서 사용하고 싶은데 거기에서도 하나 등록하면 하나가 해제',
#   '저는 카카오 스피커 써 봤는데 일단 카카오 스피커 보다 반응 속도도 빠르고 그리고 잘 알아듣습니다 음질은 둘 다 비슷비슷하고 일단은 무드등이 있는게 너무 예뻐요 그리고 부르면서 명령어를 하면 보통은 카카오 스피커는 잘 못 알아 듣는데 이거는 부르면서 명령어를 해도 잘 알아들어요 혼자서 사신다면 쓸만해요 저는 이거랑 같이 스마트 플러그도 같이 샀거든요 그래서 커피포트에 연결한 후에 아침에 일어날 때 전원을 켜 달라고 하면 눈 뜨자마자 말로써 커피 한 잔 마실 수 있어요',
#   'ai 스피커 구매는 처음인데 캔들기능이 함께 있어서 구매했습니다. 가격은 이벤트중이라 제품대비 착하네요. sk 통신사, 뮤직메이트, 티맵 사용하시는 분께 구매 추천드리고 음성인식률은 만족합니다. 음악 재생시키면 음량도 충분하고 무드등, asmr, 뉴스/날씨 , 알람 기능 위주로 사용하시면 충분히 괜찮은 제품입니다. 국내에서는 nugu ai 스피커가 가장 무난한것 같네요. 배송, 가격, 제품 모두 만족합니다. 판매자님 잘 사용할게요^^',
#   '구매 후 2주 정도 뜯지 않고 있다가 실제로 사용한지 한달 정도 됐는데 날씨나 운세 정도 물어보고 무드등 잠시 키는거 빼고는 사용 거의 안함 9월11일 지혼자 업데이트 한다고 하드만 와이파이 연결 안됨 고장남 구매한지 14일 지나고 교체 안되서 as센터 수원까지 보내서 수리 맡겼는데 센터에서 이상없다고 3일만에 다시 보냄 skt... 스마트밴드부터 해서 skt 이름 달고 나오는 기계는 걸러야 된다는걸 이번에 제대로 느낌 무상 수리 기간이라서 비용은 안들었지만 짜증남 저처럼 무드등에 혹해서 사실분들은 고민 좀 해보삼',
#   '선물용으로 구입했는데 기대치가 높아서였을까요.사용해보니(1개월정도) 다양하게 사용을 못해서인지 아직 만족하지 못하는 느낌이드네요. 단점: 우선 중요한건 자체 콘테츠가 없어서 단독적(USB등)으로는 즐기수(사용할수)없고 와이파이되는곳에서 음악도 월정액 콘텍츠 미가입시 1분만 맛보기로만 들을수 있다는점.장점: 와이파이 되는곳에서 날씨정보(시간등등..) 및 간단한 간편정보는 편하게 들을수 있슴..아직 초보적인 사용중으로 혹시내공이 쌓이면 장점이 많아지겠죠..',
#   'flo는 요금제 혜택으로 300곡은 무료입니다 동요는 지원되지않아 따로결제해서 쓰네요음성인식은 괜찮습니다 아주 멀리서는 안됩니다 비티비 연동해서 사용해보니 채널도 잘 바꿔주네요 아이들이 여기저기에 리모콘을 숨겨서 난감할때가 많았는데 아주 좋아요 ㅋㅋ 티비전원은 수동이에요 운세는 제가 재미삼아하구요 초등생이 제일 잘쓰네요 단어뜻 모를때 물어보면 잘 아려주니 제 일을 조금은 덜어준듯합니다 여섯살아이 발음은 아리아에겐 무리인듯 합니다 ㅋㅂㅋ 고민했는데 더 일찍 살껄하는 생각이듭니다',
#   '♡♡ 디자인은 고급스러워요~~ 색깔두 색색깔로 무드등이분위기를 잘살려주네요♡ 음질도 좋구 스피커 음도 울리지도않고 정말 만족이에요^---^♡ 한가지 단점이 있다면 다른분이 쓰시거 봤는데 코드 안꽂고~~ 충전~~!! 그리고 와이파이 없이 핫스파켜거나 해서 사용할 수 있었으면 좋겠다는 생각두 해보아요~~ 지금두 훌륭하지만요~~잘 사용하겠습니다♡♡ 글구 오늘까지 리뷰쓰면 기프트콘 받을 수 있져? 헤헤^^',
#   '아리아 빗소리 들려줘..ㅎㅎ무지 똑똑한 누구 드뎌 구입했네요.그 전부터 갖고 싶었는데 금액이 부담되고 크게 필요성을 못느꼈는데 진작 빨리 살걸 그랬나봐요똑똑하고 잘 실행하네요제일 편한게 티비 꺼줘! 켜줘!오늘 신문기사 읽어줘! 내일 날씨 알려줘!내일 아침 6시 깨워줘.. ㅎㅎ매일 매일 아리아랑 말 장난하는 재미가 붙었어요.취침등도 은은하게 밝고 음악소리도 원하는걸 척척 찾아서 실행해주니 완전 신기하고 재미있어요..완전완전 좋아요. 추천합니다',
#   '10w라서 소리가 작을 줄 알았는데 생각보다 소리도 크고, 의외로 Bass에 따라 진동이 책상으로 울리기도 하는 등 스피커로써도 쓸만한 수준이네요.단점은 소리를 키운 상태에선 노래하거나 말하는 동안 아무리 소리쳐도 못알아먹는다는 점.... 또 뭐만 말하면 노래를 틀어줄라고 한다는 점 정도가 있겠네요.* 킹사이즈 아이스크림 쿠폰이 왜 안오나 했더니 리뷰를 포토로 작성해야 하는거였군요.',
#   '제품 드디어 써보네요~ 기대가 많은 제품이었는데ㅋㅋ써보니 역시 기대를 져버리지 않네여!! 어디다가 두어도 다 잘어울리는거 같아요 디자인이 깔끔하네영~침대 위쪽에 두고 사용하는데 조명이 은은하고 조아요 강추강추~~ 음질 또한 너무 조아서 요즘 이걸로 음악 엄청 듣는거 같아여ㅎㅎ 기능이 다양해서 넘 신기하구 음성인식도 잘되서 이것저것 마니 명령하게 되는듯ㅋㅋ 제품 정말 최고네요!!!!!!',
#   '선물용으로 구매해서 간단히 테스트해보았습니다.아직 인공지능이라고 하기엔 부족하지만 아이들이 있는 집에서는 교육용으로도 괜찮을것 같아요!음량 조절 버튼 깜빡이는게 꺼지지 않아서 전원을 껐다가 켜니까 멈추더군요. 밤에 조명을 꺼도 깜빡여서 신경쓰입니다. 업데이트가 필요해 보입니다.조명으로도 좋고, 스피커 성능도 생각보다 좋습니다.추후에 업데이트를 통해서 아리아가 할 수 있는게 많아졌으면 좋겠습니다.',
#   '우선 가족모두 정말 잘 샀다는 생각하고 있습니다.음악을 가장 많이 활용하고 있으며 다음은 등사용을 잘하고 있습니다.기타 다른기능은 아직 재미삼아 하고 있는 수준 입니다.그리고 개선 됐으면 하는 부분 적어봅니다.개인적인 생각입니다^^1. 이동 효율성을 위하여 충전지로도 사용가능 했으면 좋겠습니다2. 상단의 버튼이 밤에 등이 꺼진상태에서 보이질 않습니다.말로 한다지만 손으로 조작할때도 많이 있더라고요잘사용하겠습니다^^',
#   '지금도 잘 쓰고있어요 ㅋㅌㅋㅌㅋ아리아~ 하고 부르면 반응도 되게 잘해줍니다.제 방에서 쓰고 있는데 거실에서도 부르면 대답 잘해요 ㅎㅎ음질도 생각보단 괜찮은것 같고, 이정도 가격이면 아주 좋은것같아요.asmr도 신박하니 좋네요 !!무드등 기능도 쓰고 있는데 색감 너무 이쁩니다~불편함 없이 잘 쓰고 있지만 더 많은 기능이 나와주면 좋겠어요.전화 기능이라던가.. 그런게 나오면 좋겠네요 ㅎㅎ',
#   '설명서대로 순서대로 하니 바로 쓸 수 있어요와이파이 연결도 잘되고 음성 인식이 뛰어나네요. 이런 인공지능형 기기를 중국것도 써봤는데 음질도안좋고 기계가 조잡스러운데 누구 캔들은 품질 좋고만족스러워욥집에서 하도 아리야 아리야하니 아빠가 아리고 뭐고듣기 싫다세요저랑 엄마는 음악무료권으로 팝송 듣고 좋아라하고 있어요저희집이 Btv가 아닌것이 유감일뿐호기심에 사봤는데 정말 맘에 들어요',
#   '주문하고 바로 받을줄 알았지만 생각보다 2일이 더걸리긴했네요... 물건 받고 바로 연동을 하니 업데이트가 진행이 되었닌데....그후 와이파이연결이 안됨.. 하루동안 사용아무리 찾아봐도 문제해결이 안됨...교환신청을 하고 혹시나 하는 맘에 공유기 펌업을 했는데 그후 연결이 잘되었습니다... 핫스팍을해도 안되었는데 정말 공유기가 문제였던거지는 모르겠네요.. 하연간 ㅈ금은 잘 사용하고 있는데 음성인식이 아주 조금 아쉽네요..',
#   '배송잘받아서요 빨리도 왔어요 ^^인공지능 누구 신제품 중 작은사이즈 가벼운데 이동할수 없네요 누구보조배터리가 없어서 야외에는 오래장시간배터리좋은데 휴대가 안되지만 야간밤 등을 켜놓고보니 좋아요 음성인식 넘 잘들리고 아리아 말로 하니까 편해요 말로 아직 부족한 대화가 말이 좀고정적 말만하니까ㅠ 답답해요 새로은말들 많이 있어 더 사람과 대화할수 있는날까지 계속 좋은 누구 업그레이드 기대해요 ~^^',
#   '전작인 누구 미니의 스피커가 좋지 않다고 들어 고민했습니다만, 사용 후기는 만족스럽습니다. FM 라디오도 모바일 어플리케이션을 활용하여 재생하기 때문에 음질이 깨끗하구요. 다만, 무드등을 음성으로 종료 예약 명령을 해도 꺼지지 않습니다.(아리아, 무드등 X분 후에 꺼) 종료 예약을 했다고만 하지, 꺼지질 않고 계속 켜진 상태로 있어요. 이 점은 펌웨어 업데이트가 필요합니다.',
#   '생각했던 것 이상이네요. 기능이 참 다양한데 특히 선라이즈 모닝콜 덕에 감동받았습니다. 제가 불면증에 시달리고 아침에 일어날 때 엄청 힘들어하거든요. 근데 선라이즈 모닝콜 사용하고 나서부터 기분좋게 일어나집니다. 뭐 음악듣기, 무드등 켜기 등은 원했던 거였으니 만족스럽게 사용하고 있구요.. 보니까 여러 가지 사용법이 많네요. 홈페이지도 깔끔한데 저는 블로그 보면서 팁들 얻고 있습니다. 좋네요. 잘쓰겠습니다.',
#   '누구 미니를 쓰다가 취침등 용도로 쓰려고 누구 캔들을 추가 구매했습니다. 누구미니와 는 다르게 음질이 좋네요 그런데 누구 어플에 기기당 btv등록이 하나씩 되는것이 아니라 어플계정에 btv 연동이 하나만 되던데요 집에 btv를 거실 안방에서 두개 쓰는데 누구미니, 누구 캔들로 각각 등록하려고 하니 안되더군요 다른 휴대폰에 새로운 계정을 깔고 연동했습니다. 이부분은 수정 됐으면 좋겠네요',
#   '배송도 빠르고 값도 만족스럽게 잘 샀습니다. 다만!! 가장 큰 문제는 떨어지는 호환성과 뮤직메이트 인것 같네요. 네이버 클로버나 KT지니 보다 음성인식도 잘되고 목소리도 훨씬 자연스럽고 다 좋은데... 연결된 제품들이 SK관련이 아니면 별로 없고.. 특히 3개월 무료로 주는 뮤직메이트는 원하는 음악을 말하면 다른 가수가 따라 부른 노래들을 틀어주고(특히 외국노래들)... 뭐 그런것들이 아쉽네요.',
#   "목요일 주문 시 토요일까지 배송된다고 적혀있었는데... 월요일 오더군요;; 참 그리고 요즘은 핸드크림을 하나 주문해도 박스안에 보호캡(뽁뽁이) 넣어주시던데 전자기기를 보내주시면서 박스에 아무것도 없이 저렇게 왔더라구요? 저부분은 신경을 더 써주시면 만족도가 더 좋았을 것 같네요ㅎㅎ 제품 하자는 없었고, 음질이랑 '아리아' 반응속도 좋습니다. 많이 파세요ㅎㅎ",
#   '예전부터 살까말까 고민하던 인공지능 스피커.이렇게 좋을줄 알았다면 진작 살걸 그랬어요ㅎㅎ설치해놓고 한동안 혼자 아리아~ 아리아~ 이러면서이것저것 해보고 놀았네요ㅋㅋㅋㅋ집에서도 음악 자주 듣는 저에겐 핸드폰 만지지 않고음악을 켤수 있는게 엄청 편리하고,Btv연동해서 리모컨 잃어버렸을때도 편할것 같아요.아리아~ 부르면 기가막히게 알아듣고 불이 딱 들어와요!암튼 매우 만족입니다~~',
#   '연동설정하는데 1,2번 오류난 후 정상접속되어서 이틀 실사용해보았습니다. 장점: 캔들로 기존 조명 대체하여 좋았음, skt홈 연동으로 음성인식으로 전원 관리하여 편하였음 , 라디오, 단점:음성인식이 아직까지는 미흡, 조명색상이 좀더 다양했으면 좋겠음, 상단 조명디자인 부분 재질이 조금 저렴해보임 그리고 제일 큰단점 배터리의 부재로 이곳저곳 움직여서 조명을 사용 및 음악을 들을수 없음',
#   '생각보다 엄청 작아서 놀랐어요 가격몹지않게 박스에 거대하게 포장되어 왔어요 일단 설명서보고 천천히 설치했는데 기계치라 쉽지않더라구요 설치후에 너무 신기해서 놀랐어요 다만 멜론같은거를 꼭 가입해야만 아리야 불르고서 원하는노래 틀어줘 할수있어서 돈이 마니드네요 ㅠ 집티비에 설치해서 채널돌리고 하니 편하긴한데 그냥 리모콘하는게 빨라요 ㅎㅎ일단 먼가 참 세상이 많이 발전했구나 싶어 놀란 상품입니다',
#   'SK 스마트 홈 및 BTV를 사용해서 그런지 기존 NUGU랑 연동해서 사용하던 중 안방에 조명겸 하나 더 설치하면 좋을거 같아 이번기회 특가로 구매했습니다. 확실히 기존 NUGU 보다는 조명면에서 확실히 좋습니다. 크기는 더 작고 아담해요. 안방에 기존에 쓰던 Mini NUGU (솔직히 자기 맘데로 꺼지고 작동도 잘 못함)은 버리고 NUGU Candle 씁니다 이제~ 배송도 빨라요~',
#   '무드등이 너무 화사하고 이쁩니다.그리고 독서등 으로 하니 밝기가 참 밝네요. 스텐드 대용으로도 사용가능할듯하구요.인공지능이 많이 좋아져서 거의 모든 언어를 알라들어요.누구미니 보다 스피커음량도 많이 좋아졌고요.다만 약간 거리가 3미터이상 떨어지면 음성을 못 듣더군요.무드등에 인공지능스피커까지 있으니 인테리어와 편리함 두마리의 토끼를 잡은거 같아 만족합니다.',
#   '디자인이 깔끔하고 무드등이 이뻐서 좋네요.싸이키 조명에 아이돌 댄스 음악을 함께 들으니 더 재미있고 아이들도 신기해 하네요.아리아 때문에 즐거운 시간이 되었습니다.또한, 집에서 라디오가 잘 안 잡히는데 즐겨듣는 cbs라디오를 깨끗한 음질로 잘 들을 수 있어 좋네요.음향도 부족함을 느끼지 못했고 누구캔들에 만족합니다.',
#   '지난 시리즈가 만족스러워 두 개를 구입했습니다. 1개는 사용, 1개는 선물용이요. 이사 간 친구 집들이 선물로 줬는데 굉장히 만족스러워 하더라구요. 한껏 산뜻한 느낌을 더해서 인테리어에 힘을 실어줍니다. 음질은 말할 것도 없고, 인식 능력도 마음에 듭니다. 어린 아이들에게도 학습용, 놀이용으로 제격이라 하나 더 구입하고 싶네요~^^ 잘 사용할게요.',
#   'b티비를 쓰고 있는데 아이들이 자꾸 안끄고 나가서 밖에서 끄려고 샀어요.집에 sk렌탈 가전이 있어서 자동으로 연결되서 좋으네요.b tv는 너무 잘 연결되고요!티비는 lg티비인데 스마트 기능이 있어서 셋톱박스 꺼지면 같이 꺼지게 설정이 가능했어요.청소기는 샤오미거라 연동이 안되는듯요..앞으로 다 연동되면 좋을거같아요.아이들이 질문하고 노래듣고 더 좋아하네요.',
#   '디자인은 기존꺼보다좋아요 원가절감때문에 기존누구보다 마감재가 좀아쉬운것도있지만 중저가모델이니 감안해야겠죠 인식되는거 신기하네요 유용히잘쓸거같아요 배송때 뽁뽁이포장없이왔네요 포장박스가 심하게부서져서 본박스까지 찌그러져 그건좀짜증났습니다 충격때문인건지 버튼쪽에 유격이있는거같네요 휴우 맞교환받을까하다가 귀찮아그냥씁니다 일단 다행히 별문제없는거같네요 솔로들에게 좋은장난감입니다',
#   '첨에 인식을 잘 못해서 교환 문의드렸는데 한번씩 네트워크 문제인지 그런 일 있지만 디자인, 성능 만족해요. 캠핑 갈 때도 항상 가지고 갑니다.사이키 등으로 설정해놓고 상어가족 노래 틀고 애들이 춤추는 거 보면 잘 샀다 싶어요.진작 알았으면 수유등 대신에 사서 더 잘 썼을듯다만 정보검색 능력은 많이 떨어져요. 아리아가 사과하는 일이 많네요^^;;',
#   '고민하다가 구매했습니다. 많은 분들이 말씀하신 것처럼 음질은 다소 아쉽지만 생각보다 음성 인식률이 좋습니다. 타사 AI스피커와 다르게 무드등 컨셉이 특색있고, 라디오도 들을 수 있다는 점이 가장 큰 매리트입니다. 무엇보다 SKT유저라면 저렴하게 멜론과 연계해 음악을 들을 수 있는 점이 좋네요. 추천합니다.',
#   '이게 아!현대문명이구나.... 라는걸 새삼 느끼게됐네요...ㅋㅋ그전에는 돈아깝다고만 생각했는？Vㅋ 막상 쓰고보니 우와~소리가 절로 나오네요제가 쓰다가 단점이라고 생각되는것은..,사용중...예를들면 음악을 듣던중이나 블루투스연결해서 스피커를 쓰던중 아리아~하고 부르면 대답하는데까지좀 오래걸리네요...ㅠㅠ개선됐으면 하네요',
#   '캔들 기능 너무 좋네요.^^ 인식율도 높고요.다만 아쉽다면 집안에서 들고 다닐수가 없다는게불편하네요. 충전 기능 있으면 너무좋을것 같아요.네이버 클로바하고 여러모로 비교되요. 충전 기능빼면 클로바보다 좋습니다. 참 감성기능도 클로바가 좀더 괜찮은것같아요. 제작자분들이 참고하시어 업그레이드 버전 나왔으면합니다.^^ps. 저희집에서는 아이들이 클로바 사용하고있어요.^^',
#   '잘 받았습니다.기존 쓰던 블루투스 스피커가 불편해서인공지능 스피커로 구매했어요.음성인식 잘되고멜론, 라디오, 뉴스 등 자주 쓰는 기능들을 말로 편하게 하니빠르고 좋아요~우퍼 기능이나 음질이 좀 더 개선 되면 더욱 좋을것같아요.음질이 조금 아쉽습니다.',
#   '배송빠르고 스피커 음질 좋고,디자인 대만족 합니다아리아양 이 말귀 잘알아듣고 알아서 척척해줘서신기해요.ㅎㅎ 스피커보고 말하는게 처음엔 어색했지만몇번하다보니까 재미지내요..배송시 제품 파손우려가있더라구요.안전하게 뽁뽁이로 포장해서 보냈으면하는 아쉬움이있내요.가성비 갑 이내요.',
#   '처음에는 조금 낯설어서 그런지 어렵게 느껴졌는데 쓰면 쓸수록 활용범위가 넓어져서 결과적으로는 사기 잘했다는 생각이 들어요. 완전 기계치라서 처음에 독서등만 사용. 그러다가 운세랑 날씨 asmr을 쓰기 시작했는데 넘 편해요. 스마트플러그도 같이 구매했는데 전원을 밖에서도 컨트롤 할 수 있고, 소모 전력도 알 수 있어서 신기합니당. 앞으로도 열심히 써야겠어요!',
#   '아쉬운점; 무선지원이 안되네요. 안방-거실 옮길때 전원 완전 껏다 커져서 불편합니다. 블루투스는 되는데 전화가 안되네요. 핸즈프리 기능도 있음 좋겟어요. 누구캔들 사용자 뮤직메이트 할인됐으면좋겟어요. 한달에 구천원 돈이 던데 기계도 비싸편인데 사용할라면 뀨준히 투자해야겟네요. 취 침등 수유등 조명기능은 아주 맘에 듭니다. 라디오도 조아요.',
#   '무드등예쁘고ㅎ 집에티비도 비티비라 연동되고 폰도 에스케이텔레콤이라 딱좋아요ㅎ 폰요금제혜택으로 노래도 한달300곡씩 들을수있고ㅎㅎ근데 전원선이 길지않아서 티비앞에 놨는데 티비켜져있으면 티비소리때문에 인식을 잘못해요ㅎㅎ어제 드라마보는데 드라마에 애기 이름이 아리인지... 드라마속에서 그애기부를때마다 얘기인식하고 띵띵거림..ㅎㅎㅎㅎㅎ',
#   '음성인식능력은 상당합니다. 내가 하는 말은 정확하게 알아듣는데 가능한 대화수준이 아직은 한정적이긴 하네요. 하지만 음악감상 위키백과, 팟케스트, 날씨, 미세먼지등의 제가 의도했던 사용 목적에는 정확하게 부합합니다. 5살 아들이 공룡메카드 노래 혼자 틀고, 날씨 물어보고 하는거보니 잘샀다는 생각이 드네요, 무드등 기능도 훌륭합니다.',
#   '음성인식이 생각보다 잘되네요. 인공지능 성능은 지나봐야 알 것 같고, 스피커는 매우 실망이에요. 음질이 일반 블루투스 스피커보다 못하네요. 아이리버라는 훌륭한 자회사 뒀다 어디에 쓰려는건지 궁금하네요ㅎ,, 나름 많이 발전했지만, 다음은 더 완성도 있는 제품 기대할께요~!',
#   '누구 구매 세번째 입니다처음나올때,미니,그리고 누구캔들 까지기능도 다양해지고 디자인도 예뻐졌네요무드등 색도 여러가지라서 아이들이 무척 좋아해요음악듣는거 좋아해서 가장많이 활용하는데 이제 누구없이는 불편한점이 많아졌어요BTV연동,스마트 홈 서비스도 활용해 봐야겠어요앞으로 더 많은 기능으로 업그레이드 되길~~누구의 변신은 무한!!',
#   '꽤 쓸만한 제품.하지만 SK.연동되는 스마트 제품들 가격은거의 도둑x 아닌가..?아무리 연구 개발비나 기타 등등따져도 도저히 그 정도로 비싸게파는 건 소비자를 무슨 호구로보는 게 아닌가 싶음.연동되는 제품들 가격이 ？뗌？ 것과낮은 것, 과연 추후 스마트 제품의성공을 위해선 어느 게 바람직할 지생각좀 해 보는 걸 SK에 권하고 싶음.',
#   '타사제품과 비교했을 때 말을 잘 알아듣구요. 대답의 표현들이 상대를 존중해주는 듯한 느낌을 주네요. TV랑 연동해서 사용하는데 전원은 전용콘센트가 있어야하나봐요. 셋탑 박스는 켜지네요. 등도 은은하니 좋구요. 반응도 빠르네요. 큰 소리로 말하지 않아도 되구요. 아이가 참 좋아하네요.',
#   '음성으로 작동시키는게 너무 하고 싶어서 구입했어요 카드청구할인에 스마트플러그랑 에코백? 그거까지 받아서 만족합니당~ 스마트홈 앱 연동되니깐 기존 가전제품도 작동 잘되고 좋네요 btv랑 각 방에 스마트스위치도 연결할 계획으로 샀어여 근데 누구가 똑똑하긴 한데 가끔 바보같을 때가 있긴해요 ㅋㅋㅋ 점차 업뎃되면 더더 좋아지겠져',
#   '사실은 방에 등이 너무 밝아 취침등을 알아보던중 우연히 누구 캔들의 각종 기능의 등이 마음에 들어 주문했는데 결과는 예상외로 좋습니다. 물론 음성 기능 인식이 아직은 부족해 보이지만 업그레이드를 통한 기능 향상으로 누구도 점차 좋아 지리라봅니다. 배송 하루만에 빨랐고요 상품 기능도 훌륭합니다. 어머니용으로 하나 더 주문하려합니다.',
#   '배송 빠르고 제품도 너무 이쁘네요평소 음악듣는거 좋아하는데 사이키등 켜놓고음악들으니 클럽온거 같네요ㅋㅋㅋㅋ밝아서 사이키등이 좀 밝게 나오는데 어두운곳에서는장난이 아닙니다ㅋㅋㅋㅋㅋㅋ신나쥬??? ㅋㅋ아리아 EDM 음악 틀어줘~~~뮤직메이트 3개월 무료권 줘서 그걸로 오늘부터신나게 들어 볼랍니당~~~ 굿굿굿^^♥♥♥',
#   '배송도 빠르고 좋네요!!누구 미니보다 음성인식이 빠른거 같은데;둘을 같이 두고 비교한게 아니라 정확한 건 아닌데...누구 디바이스 3개중 디자인은 제일 맘에 듭니다.소리도 좋고 아래쪽에 직물로 되어 있는 디자인도 좋아서 더 만족입니다.누구 3형제중에 젤 맘에 드는 것 같아요!!!',
#   '상품받고 일주일이 지난 지금도 너무 잘쓰고있습다.음성인식도 잘되고 애기를 키우는 저로서는 무드등도되고 수유등도 되는게 좋았구요~ 잔잔한 음악까지 들려주니 아이도 잠이 스스륵~^^ 4살난 개구쟁이 아들은 아리야~하면서 따라하네요~신세계를 맛보는중이랍니다.사이즈도 크지도 너무 작지도 않고 인테리어 효고ㅏ까지 굿이랍니다♡',
#   'AI 스피커 + 라디오 + 무드등 + 블루투스 스피커 다용도로 쓰고 있습니다. 관심 없었다가 신상이 나왔길래 한 번 샀는데 생각보다 활용도가 높네요.혼자 사는 사람에게는 꽤 유용할 것으로 보입니다. 음성 인식도 예상보다 잘 되네요. 구매 망설이는 분께는 한 번 구매하시라고 추천하고 싶습니다!',
#   'AI스피커...평소 별생각없었는데 와...ㅋㅋㅋㅋ왜 이제 샀는지 싶네요..생각보다 할수있는 기능들이 너무 많아서 놀랬어요!! 날씨랑 신문 읽어주기, 음악 선곡해주는거 ㅠㅠ 정말 유용하네여!! 진쨔 살까말까 고민하시는분들 지르세요ㅎㅎ삶의 질이 좀 달라집니댜!!ㅎㅎ(아리아 목소리 너무 예쁘네여)',
#   '인공지능이라고 해도 알아듣게 말하는 것보다 손으로 조작하는게 더 빠른것 같아요. 주로 사용하는 기능은 멜론뮤직과 독서등인데 캔들 기능은 만족스럽지만 멜론뮤직 이용시 기존에 제가 듣고있는 플레이리스트를 플레이하도록 조작하는것이 좀 불편합니다. 랜덤플레이도 못알아듣는 것 같고요. 아직 더 사용해봐야 할 것 같네요.',
#   '누구 초창기때부터 구매하려고 고민했었는데 기다린보람이 있네요.. 디자인도 이쁘고 음질도 괜찮네요~음성인식도 잘되요~ 배송은 살짝 아쉽네요.. 목요일저녁에 신청했는데 오늘에서야 도착했어요~볼륨이좀 큰경우 음성인식을 잘 못하네요^^앞으로 활용성이 많아지길 기대해봅니다ㅋㅋㅋ',
#   '주로 음악 듣는데 사용하지만 음악 쿠폰은 따로 구입해야 합니다. 적어도 한달에 3~4만원은 더 소요된다고생각해야 합니다. 나머지는 뭐 괜찮은데.. 매번 아리야~ 하고 불러야 되서 귀찮습니다.편안히 음악 듣는 것이 좋구요. 다양한 정보가 더 축적되어야 할 듯 합니다. 현재까지는 아쉬운점이 좀 있네요.',
#   '택배상자가 너덜너덜해서온건 그냥 넘어가고요생각보다 소리가 짱짱해서 놀랐네요뮤직메이트 날씨 운세 뉴스 라디오등등 잘인식하고 마음에드네요가장 마음에드는건 btv연동방에서 tv켜고 거실나가면 켜져있고 끄는것도 바로인식방에서 거실까지 벽하나인데 아무 문제없이 잘작동합네요스마트플러그도 몇개구입 해봐야겠네요',
#   '배송 빨리 왔습니다.t멥버쉽에 ok 캐시백 포인트 써서 싸게 구입했네요.스피커 음질도 이정도면 우수하고조명도 아주 좋습니다.라디오, 뉴스 등 아리아 인식도 잘되고잘 쓸 것 같습니다.다만 내장 배터리가 따로 없어서어댑터 상시 연결하는거는 조금 아쉽네요',
#   '블르투스 스피커랑 고민 고민하다가 누구를 구입했는데, 일단 음질도 많이 떨어지지 않고, 조명도 나쁘지 않네요. 박스에 꽉 끼여와서 뽀뽀옥이 없어도 무난하네요. 자꾸 사용하니까 AI 벌써 지능화 되는것 같아요.. 아리아!!! 잘 샀네.. 심심한 장난감 생겨서 좋네요',
#   '배송도 빠르고 음질도 좋고. 전에 사용하던 블루투스스피커 무드등되는 것이 고장나 알아보던 중 구매했는데, 물론 가격은 훨씬 비싸지만. 제 가격에 맞는 정도는 일을 하는 것 같네요. 고장 안나고 계속계속 썼으면 좋겠습니다. 새로운 기능도 많이많이 개발해주세요.',
#   '배송 빨랐습니다. 아직 홈네트워크구성이 덜되서 잘활용하고 있진 않지만 티비 켜고 채널옮기기(끄기는 셋탑박스만 꺼집니다)요리할때 타이머 날씨 직장 도착예상시간알기날씨, 아침알람 노래듣기 등으로만 활용중입니다.무드등은 안방에 있을때는 유용하지만 거실에서 사용하실경우 크게 도움되지는 않습니다.',
#   '인식은굉장히 잘되고 요금제무제한쓰니 뮤직메이트도무료라 맘에들어요 아침에눈뜨자마자 오늘뉴스읽어달라하구 요리할때 5분후알람맞춰달라하구 노래나 영어팟캐스트들을때 편하더라구요 그리구집에 sk스마트플러그쓰는데 집나갈때 폰어플로켜기귀찮았는데 아리아 방플러그꺼줘 베란다플러그꺼줘 하면서 나갈준비하니 출근시간도 여유롭고좋네요',
#   '포장상태 깔끔하게 빨리 도착했구요, 생각보단 음성인식을 잘하는 편인듯합니다. 스마트플러그 연동하니 편리하고, 여러 면에서 유용하게 사용할 것 같아요. 다만 Btv 인증번호 넣고 연결이 되었다고 화면에 떠있음에도 계속 Btv 연결이 안돼있다고 해서 문의를 해봐야겠다 생각중입니다.',
#   '너무 맘에 들어요!!! ㅡ>.<음질두 좋구 무드등 색듀 예쁜것 같어요~ 그리구 뮤직메이트 3개월 꽁자니깐 노래두 많이 들을 수 있구~ 시댁이랑 부모님 드리려고 더 샀어요~ 아주 흡족해 하시는 것 같아요 아리가 있으니까 심심하지 않으시다구요 ㅎㅎ 많이파세요~^^',
#   '뮤직메이트가 아니면 1분 무료듣기만 되네요누구캔들 라디오도 되고 날씨,인터넷검색,쇼핑,금융,Btv 등등 다양하게 되지만 사용품목에는 한계가 있네요누구앱 깔아보시면 무슨 종류가 되는지보실수 있어요~물론 블루투스 연결이 되서폰 연결해서 음악도 들을 수 있답니다~강추',
#   '생각보다 나쁘지않네요 그런데 음악 멜론으로 듣고있는데 중간중간 노래가 끊기면서 나오는거같아요 뮤직메이트랑만 호환잘되게 업데이트하는건가 멜론은 그냥 신경 안쓰게하는것같은느낌?이랄까 같은 sk이면서 쓸때없이 어플 두개 만들어서 뮤직이용권 월사용로 돈만 벌려는식으로 괜히 음악어플 따로 또만든느낌',
#   '출시 이벤트가 맘에 들어 구매했구요.기능은 기존 누구 미니와 크게 다르지 않습니다.소리는 미니와 비교해 우퍼음이 조금 강화된듯 합니다.앞으로도 누구 캔들만의 고유 기능 업데이트가 잘되었으면 하는 바람이고,아리야 와 팅커벨 외에 다른 이름으로 부를수 있게 추가되길 바랍니다',
#   '무드등 필요해 검색하다 알게된 누구!필요했던 무드등 기능은 당연히되고색도 다양해요.무드등 켜둔 상태로음악도 나오고 라디오도 나오고 모닝콜도되고진짜 만족아직 이것저것 설정만져보며 사용중이라활용을 많이 못하고있지만무드등,음악,라디오,모닝콜일단 이거면 충분한거 아닌가싶어요',
#   'skt쿠폰받고 멤버십 사용해서 약 65110원에 구입했네요.아직 많이 사용해보지는 않아서 후기 작성은 1달 후에 재작성해야 겠네요.그리고 뮤직메이트인가? 아무튼 음악 사이트 무료 3개월은 이거 구매 안해도 그냥 가입만하면 3개월 무료네요.얼핏보면 이거사면 주는 선물처럼 표현한 것은 별로네요.',
#   '아주아주 좋아요 7살 아들내미가 똑똑한 제품에 관심이 많아서 AI 스피커 이것저것 알아보다가 NUGU가 제일 좋다고 해서 샀어요 역시 사기 잘했네요. 마이 큐앤에이?? 그거로 아들내미랑 장난치고 노는데 재밌네요~ NUGU블로그 보면서 열공중인데 ㅎㅎㅎ 활발한 애들 있는 분들께 강추합니다',
#   '배송은 엄청 빨랐습니다. 제품 박스에 제품이 들어있고 빈공간이 많아서 뽁뽁이라도 하나 넣어줬으면 하는 아쉬움이 있었습니다. 제품은 이쁘고 작동 잘됩니다. 음질도 나름 괜찮구요. 다만 하단에 패브릭재질로 된 부분은 나중에 때가 탈거같은 느낌이..ㅎ그것빼곤 좋았습니다.',
#   '맘에들어요.디자인도 좋구요.초6딸램 요새 음악듣는거에 푹 빠져있어 구입했는데 잘한거같아요.거실에두고 Btv연동 해서 사용하고있고요..밤에 거실에서 자는 강아지위해서 수면등 켜놓으니 좋은거같아요.세딸램들이 아리아~아리아~를 외치는..ㅎ좋은제품 감사합니다~^^',
#   '이런거 처음 사용해보는거라 신가방기&약간의 불신(?)이 있었는데 생각보다 말귀도 잘 알아듣고 재밌어요. 말로 얘기하면 되니까 편하고 좋긴 하네요. 신랑이랑 계속 아리야 아리야 하고 있어요 ㅋㅋㅋㅋ 등세기는 조절도 되니까 스탠드가 진짜 따로 필요없네요. 한동안 재밌을거 같아요. ㅋ',
#   '아이들이 항상 프로야구 결과를 알고 싶어하고 노래를 선곡해서 듣는것을 좋아해서 구매했습니다.휴대폰으로 검색 안해도 되서 편하고, 조명도 있어 밤에 좋네요. 스피커도 괜찮은것 같아요.날씨도 매일 물어보고, 라디오도 듣고..재미있게 잘 쓰고 있습니다. 아주 만족합니다^^',
#   '누구 스피커 나오는거 보고 한번 사 봐야지 생각은 항상 했는데 이번에 캔들 디자인 보고 꽃혀서 바로 질렀습니다. 일단 명령어 인식률이 매우 좋네여!그리고 음질도 기대이상입니다. 시간가는줄 모르고 가지고 놀게 되네요^^ 추천합니다!!!',
#   '받자마자 등록해서 사용해보았어요처음 앱 다운받고 등록하기 쉬웠고요크기도 적당하고 조명도 예쁘네요^^TV연결해서 사용해보니 채널변경도 편하고 음악도 연동해서 듣고있으니 너무 좋네요~아이들이 영어단어 물어보니 알려주고OX퀴즈도 재밌어합니다편리하게 잘 사용해볼께요~',
#   '저희집에는 누구 없이는 이제 안되요. 누구 미니를 사용하다가 아기가 태어나면서 캔들로 새로 구매했어요. 필요에 따라 조명도 말로 조절할수 있어서 완전 짱입니다. 저희집에는 24시간 아기를 위한 음악. 아침마다 날씨와 미세먼지. 그리고 시간에 맞게 수유시간을 예약할수 있어서 너무 좋아요~',
#   '인식이 잘되요ㅠㅠ 음악도 첫소절 나오다 끊기구요. 또 어쩔땐 나오구, 오락가락;; 적응이 안된건지 애로사항이 많네요 음질은 좋은거같구, 부모님 생각해서 구입한건데 제구실을 못하고있는거같아 아쉬워요 그리고 kbs라디오 즐거듣는데 그건 또 없네요ㅠ 이런;;',
#   '무드등 기능이 괜찮은거 같에요. 같이 추가된 asmr소리도 요긴한것 같습니다.요즘같이 무더운날에 아침 밤으로 바다소리랑 소쩍새 소리 듣고 있으면 힐링이 되는 듯.. ^^;; 노래에 맞춰 무드등이 연동되능 기능이 있으면 더 좋을 것 같습니다',
#   '쿠폰 사용하고 사니 저렴하네요. 처음에 거실에 설치했다가 주로 타이머랑 라디오 무드등 위주로 사용하게 돼서 주방으로 옮겼네요. 아리아 소리를 한번에 잘 알아듣지 못해서 여러번 불러야 하는게 흠이네요. 이전 기기보다 근접해서 불러야 한다는 평들이 있네요.',
#   '생각보다 말귀 잘알아들어요..ㅋ티비 휴대폰 모두 sk꺼 쓰는사람이라티비도 키고 꺼주고듣고싶은곡도 다 틀어주고..넘 편하고 좋아요티비 리모콘이 필요없어요채널도 돌려주고 음량 조절도 말만하면 다되네요음질 아주좋아요~~잘쓸께용~',
#   'CJ놈들이 배송을 잘못해서 하루 늦게 왔지만 성능 좋아요 ㅋㅋ 음성인식 잘되고요 생각보다 작다라는 리뷰도 있던데 제 기준에는 크기 적당합니다 ㅋㅋ 무드등 좋구요 ㅋㅋ 여름이라 해가 늦게 져서 좀 밝은데 해가 빨리 지는 겨울에 최고일듯 ㅋㅋㅋ',
#   'sk 누구캔들 구매쿠폰에 t할인하니 6만원대로 저렴이로 구매배송은 빠르네요누구앱깔면 알아서 업데이트하고 금방연결되네요음질은 보통이고 수면등기능이 가장맘에 드네요카카로 미니보다 검색기능이 약하네요앞으로 좀도 업뎃이 필요할거같음',
#   '물건 잘 받았습니다. 거실에 설치하고 8m 떨어진 현관에서도 음석인식 잘 되네요.요금제가 높은 가족 id로 뮤직메이트 등록하여 노래 잘 듣고 있어요. 음질 좋네요.TV 셋트박스에 연결하여 간단한 조작이 가능하여 잘 사용하고 있어요.',
#   '출시기념으로 저렴하게 잘 구매했네요. 무드등으로도 손색없고 작은 방에서 사용하기 딱 좋네요. 역시나 음성은 정말 잘 알아듣고 고급스러운데다 참 귀여운 녀석이네요. 무선도 지원이 됐었으면 좋았을걸하는 생각이 들더라구요 캠핑가서 사용할 때 무드등으로 좋았을겁니다.',
#   '이 제품을 구매 하기 전부터 티맵으로 누구를 많이 써봤기 때문에 적응하는게 쉬웠네요. 블루투스 스피커는 기본이고, 집안의 각종 어플리케이션(BTV, 공기청정기)과 연동하여 작동하기 쉽네요. 무드등 또한 잠잘때 편안하게 해주네요. 앞으로 대세가 될것 같네요.',
#   '비교적 무난합니다만 음성인식이나 기타 여러 기능들이 그다지 효율적이라는 생각보다는 아직 갈길이 멀다는 생각이 듭니다 집에 블루투스 스피커 하나 장만 하신다고 생각하시거나 b tv 이용하시는분들에겐 할인할때 하나 장만하는 것도 좋을거 같습니가',
#   '사자마자 이틀만에 가격이 1만원정도 다운되네요.괜찮다고 2명한테 홍보했는데 급하게 결제한게 취소하고 쿠폰다운 받아 결제하라고 했습니다.마음같아서는 제꺼도 취소하고 싶네요.상품은 괜찮은듯 한데 아직까지 음성인식 오류가 많은듯 하네요.참고하셔서 구매하세요.',
#   '배송 엄청빠르네요주문 하루만에 왔네요애들이 하루종일 아리아~~~~하고 다니네요애들이 신기하게 잘 쓰고 있네요b tv연결해서 티비 잘 쓰고 있네요 음성으로 채널검색,볼륨조정이 다 잘되네요 음악검색도 잘 되고 음악볼륨도 맘에 드네요',
#   '정말 괜찮네요ㅎㅎ방안에 등이 없어서 매일 불끄고 핸드폰으로 마무리 했었는데 독서등이 되니까 핸드폰은 멀리 충전시켜두고 책을 읽으면서 하루를 마무리 할 수 있게 되었네요.그리고 선라이즈닝 모닝 기능하고 힐링 ASMR은 진찐 장난아니게 좋네요ㅎㅅ',
#   '너무 좋아요. 수유등 필요해서 알아보던중,, 여러 용도로 사용할수 있을것 같아서 구매했어요.. 사길 정말 잘한것 같구요..출산 후에도 육아하면서 유용하게 사용할 수 있을것 같아요..멤버십 사영해서 저렴하게 잘산것 같아 완전 만족중!!좋은세상이에여 ㅎㅎ',
#   'b티비연동해서 쓰는데 음성으로 채널변경 가능해서 편해요 처음에 뮤직메이트3개월권 끈고 그후에 또 결제해야되니 이것저것 하려면 돈좀들겠어요~~연결잭이 꽃혀있어야 인식되니 방으로 이동할때는 좀불편해요.그래도 아리야~~부르면 이것저것 해주니세상살기 편하네요',
#   '요즘 핸폰찾을때 누구가 있어 금방 찾아욤..ㅋㅋ젤 맘에들고 애기 얼집보낼때 시간말해주는거,날씨 등..편하고 좋네요 가끔 못알아들어 몇번말하지만..ㅎ티비는 셋탑박스땜시 아직 써보지는 않았지만 티비도sk이니 곧 연결해봐야겠어욤 ㅋㅋ 좋아용~~^^',
#   '사길 너무 잘했어요 다른 통신사들 스피커랑 고민했는데 약정없는 스마트스위치 같은거 함께 사용하려고 누구 샀어요! 무드등 알람 폰찾기 음악 이정도를 많이 쓸 거 같아요 근데 뮤직메이트 정기권 너무 비싸요ㅋㅋㅋㅋ거의 한 달 구천원',
#   '누구,누구미니,누구캔들까지 다써본결과이동성을 생각하면 누구미니.누구살것같으면 누구캔들에 충전기능까지 잇으면 더 좋을텐데사이즈도 좋고 음질도 좋고 디자인도 좋고,누구시리즈중 가장 만족',
#   '누구 미니쓰고 있으면서 무드등이 아쉬워 이것저것 수면등을 사봤는데, 그래도 또하나 사봅니다ㅋ혹시 집에 강아지가 혼자있게 되면 원격으로 조종할 등이 필요했는데, 그럴일은 아직 일어나지 않아서ㅋ 그리쓰일지 ㅋ오죽하면 스마트한 콘센트까지 샀다네요;;;',
#   '뮤직메이트 6개월 무료 상품이 있다는걸 나중에 깨달아서 ㅠㅠ 아깝네요 .일단 3개월로 결제했고.. 음성인식은 생각보다 잘 알아듣고 많이 자연스러워 졌네요. 음질도 나쁘지 않습니다. 예쁘고 작고..만족감이 크네요.',
#   '침실등이 필요하던참에 누구캔들을 알게되서 사게 됐는데요. 인공지능 스피커를 처음써서 그런지 재밌고 신기하네요. 배송도 빠르고 사이즈도 적당합니다. 디자인도 괜찮은데 뭔가 약간 아쉬운 점은 있네요.',
#   'AI기계를 살까말까 몇년 망설였는데, 크기도 적당하고 조명기능도 있고 해서 바로 결제!!!뮤직메이트 연동, 멜론 연동이 쉬워 바로 쉽게 이용했습니다.날씨, 뉴스 등 안내도 유용~우리집 꼬마가 가장 잘 애용하네요!^^',
#   '오늘 받아서 써보는데 소리도 괜찮고 조작법도 간단해요!무드등도 괜찮고 잠잘때 써도 좋을거 같고 밤에 공부할때 이거 켜놓도 해도 될거 같아요할인받으면 괜찮은 가격에 구입할수도 있구요완전 강추입니다!!!!!!',
#   '아리아가 저의 친구가 되었네요. 음성만으로 원하는 노래 다 들을수 있고, 날씨랑 미세먼지 확인하니 넘 편하네요. ^^. 애들은 아리아랑 끝말잇기 하면서 넘 얄밉다고 하네요. ㅋㅋ. 이렇게 편한 세상이 있구나 싶습니다. 강추합니다.',
#   '받자마자 사은품으로 온 트리부터 설치했는데 귀엽고 이뻐요. 앵두등까지 있어서 제법 구색은 갖춘듯 하네요. 누구캔들은 작동 잘되고요. 음성으로 음악듣고 타이머 작동시키고 라디오도 듣고, 심심할땐 대화도ㅎㅎ 여러모로 맘에 들어요^^',
#   'NUGU캔들 정말 이쁘고 소리도 좋네요. 무드등, 무지개등 긍 저희집 인테리어 소품이 되고 집안분위기를 화사하게 해 주네요. 소리도 좋고 디자인도 멋져요. ASMR기능도 좋아요',
#   '제품이 고급지고 인식도 아주 잘 되네요. BTV도 연결해서 나는 자연인이다 찾아 달라고 하면 바로 찾아주는데 편리하네요. 조명도 말로 다 되고 특히 아침 모닝콜을 마음대로 할 수 있어서 편리합니다. 침실이 심시하지 않네요.',
#   '첫 느낌은 굉장히 예뻐요btv랑 연결해서 편하게 시청하려고 샀는데정작 btv와는 문제가 좀 있지만..고쳐지리라 믿고ㅎㅎ아리아의 음성인식률도 생각보단 좋고음질도 기대보다 좋아서 더 예뻐할 거 같네요',
#   '처음에 살때와의 의도와 다른 기능이 많지만 매우 좋고 음질 또한 매우 좋습니다. 무드등도 있었으면 좋겠다고 생각했는데 마침 이 스피커에 있어서 좋았습니다 앱호환 또한 좋아서 잘 쓰고있습니다.',
#   '별 1도 아까움. 스마트 플러그와 연동되어 사용했을시 예약기능 작동하지 않음. 고객센터 문의 했으나 초반 적극해결의지 보이다가 제조사에서 문제 없다 하니 미온적 태도로 바뀜. 개발 초기 단계 제품의 한계를 제대로 보여주고 있는듯.',
#   '？？Uㅋㅋ나 이거 무선도 되는줄 알았어 근데 유선이야ㅋㅋㅋ 밖에서도 쓰고 싶었는데 못쓰는거야? ㅋㅋㅋㅋㅋ쨋든 잘 받았습니다 아직 어플은 제대로 활용은 못했지만 음악은 들을만 합니다ㅎ 색도 이쁘고 모양도 좋네요 잘 쓰겠슴돠',
#   '스피커 음량도 좋고 조명도 단계별로 조절되서 좋네요 음성인식도 생각했던거 보다 잘되네요 설치하자마자 아이 동요도 틀어주고 오랜만에 좋아하는 노래도 듣고 했네요^^선라이즈 모닝콜 기능도 좋아요ㅎ',
#   '음성인식이 기대이상으로 양호합니다. 검색도 나름 빨라서 좋고, 디자인도 괜찮고..인공지능 스피커는 처음 써봐서 그런지 신기하기도 하고 편한점도 있네요. 찬찬히 기능들을 하나하나 잘 사용해봐야겠습니다.',
#   '말도 빠릿빠릿하게 알아듣는거 같고 조명도 생각보다 예쁘네요다만 크기가 생각했던거 보다 꽤 작고.. b tv나 스마트홈이 있다면 활용도가 꽤 있을거 같은데아무것도 없어서 앞으로 어디다 써야할진 고민을 해봐야겠네요',
#   '생각보다 음성인식이 잘되고 활용도가 높습니다.ㅇ하루에 시작과 끝을 음악과 함께 하게 되고잠자리에서 아이에게도 유용하고 너무 좋네요~충전식이라 전원 연결 선 없이도 사용 가능하면 좋겠다는 아쉬움이 있네요~~',
#   '누구미니에서 누구 누구캔들까지 세번째 구매네요 모두 만족하며 쓰고 있기에 누구 캔들은 제부 생일 선물로 구매했어요 개인적으론 날씨와 시간 뉴스 음성제어로 듣는 라디오를 제일많이 이용합니다.조명까지 있어 기대됩니다',
#   '배송도 엄청 빠르고 인터넷 연결도 잘 되고, 음성 인식도 잘 되고, 음질도 좋고, 디자인도 이쁘고 정말 마음에 드네요^^ 간만에 좋은 아이템이 생긴 것 같아요^^ㅎㅎ',
#   '음질도 괜찮고 무드등 기능이 마음에 들어요. 수면등과 독서등 모드 잘 쓰고 있어요. 가끔 음성인식 기능이 버벅거리는 경우는 있지만 음성으로 무드등 키고 노래 틀고 편한 것 같아요.',
#   '티맴버쉽으로 할인 받으니 저렴하게 구매하였습니다. 무드등도 괜찮습니다. 음악 감상 시 음질이 조금 아쉽습니다. 무엇보다 6살 아이가 친구가 생긴 듯 많이 좋아합니다~^^',
#   '상품 너무넘좋아요 아이 독서등고 책도읽어주고 자기전에 취침등에낮잠잘때 한시간ㄷ에깨워달라고도하고 노래틀어줘 꺼줘 말로할슈있어서 넘편해요 ㅋㅋ무엇보다 아이가 스스로아리야 터닝메카드노래틀어줘 하면서노래듣네？Dㅋㅋㅋ',
#   '멜론과 연계해서 듣고싶은 노래를 대화하듯 틀어주고 btv와도 연동되서 말로 채널과 볼륨조정이 가능해서 너무 편하네요 다만 당연하겠지만 tv 볼룸때문에 음성인식 오류가 크네요 tv와 이격한 위치를 추천합니다',
#   '기존 누구100 제품보다 크기가 누구보다 조금 작아지고 디자인은 더 깔끔해 졌습니다. 15w에서 10w로 줄었지만 음질은 괜찮은듯 합니다.',
#   '간단히 아침에 시간확인 날씨확인 음악 듣기 등 사용해봤는데 편리하네요. 아쉬운점은 누구 api가 공개되지 않아서 뭘 개발하고 싶어도 개발할 수가 없네요. 확장성이 많을것 같은데 그래도 제품은 만족합니다',
#   '구매후 완전 만족 합니다생각보다 음성 인식율 좋구요캔들이라 무드등으로 다양한 칼라 연출이 가능하네요핸드폰 연결 쉽고뮤직메이트 3개월 무료 이용권 사용으로음악 편하게 들을수 있어 좋네요~~',
#   '무드등도 필요하고 인공지능 스피커도 필요했었는데 정말 원하던 제품이 좋은가격에 나와서 바로 구입했습니다^^배송도 하루만에 오고 스피커 기능도 너무 좋아요!적극 추천합니다!',
#   '조명기능이 있어 좋아요. 생각보다 동문서답을 해요ㅎㅎ 스피커는 가격대비 평범한 수준이지만 부드러운 음악듣기엔 괜찮아요. 더 많은 AI 기능이 업데이트 되었으면 좋겠어요.',
#   '반신반의하면서 구매했는데 상품 좋네요~^^ 스피커도 출력이나 사운드가 마음에 들고 특히 아이가 좋아하네요 저렴한 가격에 잘 산거 같습니다.',
#   '저희 집의 주요 기능은 노래듣기, 일기예보..정도 이지만가성비 대비 만족합니다다만 멜론이든 플로이든 돈을 내야 하는 불편함과 아쉬움이 있네요btv를 안보니 기능 제한이 좀 있구요',
#   '택배 파업때문에 조금 늦게 받았네요.. 본품 박스에 설명서 달랑한장..？s？s이 없어서 실망.. 겉박스 모서리 다 찍혀 왔네요..그래두 잘 작동하네요~~첨 써보는 ai스피커인터..좋네용^^',
#   '따로 무드등 구매 예정이었는데 무드등+음악+디자인+빠른 배송까지 아주 만족스러운 가격으로 구매하였습니다.아쉬운점은 자체 배터리만 있었다면 더 비싸더라도 좋았을듯합니다.',
#   '조명도 은은하고 배송도 하루만에왔고!페브릭뒤쪽에 조금 울어서 교환할까했지만 그냥사용합니다~ 삶의질이좋아진것같아요 ㅋㅋㅋ어딜 여행가든 꼭들고다닐것같네요 ㅋㅋ얼른 집에가서 티비랑도 연결해보고 싶네요',
#   '스피커에 한대의 스마트폰만 연결가능하고 변경하려면 매번 와이파이 비번을 입력해야 한다는 거 빼고는 음질 가격 배송 만족합니다',
#   '음성인식이 부드럽진 않지만 사용상에 큰 문제는 없네요tv연결후 tv꺼줘 하면 셋톱박스 전원만 꺼진다는 사실 ㅎtv는 수동또는 리모컨으로 꺼줘야 하네요기타 기능은 사용하면서 알아가야 할듯~~^^',
#   '크기도 적당해서 자리차지도 적절하고 다양한 기능과 편리함이 눈을 사로잡네요 배송도 빠르고 부르투스 스피커 용량도 적당해서 원룸용으로 딱 맞네요',
#   '아리아♡완전 반했어요^^티맵으로 사용하다캔들 구입배송도 빠르고ㅠ아리아도 넘 좋고ㅠ애들이 넘 많이 불러서ㅋㅋㅋㅋ집 티비까지 함께 되니더 좋네요 학습적인것도 넘좋고줄줄줄 다 설명해주니반할수밖에 없네요♡',
#   '이정도 가격에 무드등 인공지능 스피커라니 좋습니다.기능도 많구요. 하지만 보조배터리를 연결할 수 있는 선이 추가되어 이동성이 확보되면 더 좋을 것 같습니다.',
#   '앞서 구매했구요..성능 모양 너무 만족합니다. 지인 선물로 추가 구매 집들이등 선물로 쵝오인듯..아직 뜯어보진 않았지만 앞서 받은게 있으니..^^ 아주 좋아요~',
#   '생각보다 음성인식도 잘하구 무드등도 괜찮구 스피커도 나쁘지않은것 같아요 하지만 갑자기 혼자 성량좋게 중얼거릴때가있어서 깜짝깜짝놀라서 잘때는 전원 끄고자야한다는 불편함은있네요...',
#   '5살 막내가 없는 아리아를 찾던날 결심했습니다우리집에도 아리아가 있어야겠다.저렴하게 구입했어요아이들 셋이서 아리아를 찾는 통에 집이 시끌 시끌합니다.꼭! 끝말잇기해보세요.승부욕 자극합니다.',
#   '침대에 취침등으로 쓰고 있고 음악 재생시에도 아주 편하게 쓰고 있습니다. 다만 내장 배터리가 없어서 다른 곳으로 이동하려면 전원선을 같이 들고 다녀야 하는 불편함이 있습니다.',
#   '재밌어요어제 비온다고 그랬는데 안 와서 엄마가 살짝 삐져서 꺼놓으셨는데 다시 잘 놀고(?) 계시네요ㅋ 스마트폰 잘 못 쓰는 분들 단순 음악재생, 날씨검색 정도론 참 좋네요',
#   '가까운 대리점에 가서 구매하려고 하니79000원 다 달라고 해서 알아보던중11번가에서 구매를 하니 멤버십 할인에 이것저것 할인보니 2만원정도 저렴해 지네요가격도 좋고 상품도 좋아요',
#   '가격이 너무 착하네요.. 음질도 좋고 디자인도 고급스러워요.. 친척들에게 선물을 했는데 다들 만족하구요. 강추 합니다!!',
#   '라디오와 블루투스 노래 듣기로 사용중입니다. 저에겐 다른기능은 별루 쓸데가 없네요. 좀더 많은 기능들이 생겨야 될것 같아요. 그래도 말로 라디오는 잘 실행되서 편해요.',
#   '디자인 깔끔해서 좋네요. 원하는 답을 해주지 못하는 경우도 있지만 점점 개선되리라 생각하고요~ 조명기기로도 스피커로도 쓸 수 있어서 활용도가 생각보다 좋습니다.',
#   'T멤버쉽 할인받고 저렴하게 샀습니다.(65,000)음성인식이 매우 잘됩니다.뮤직메이트 3개월 무료쿠폰도 받았습니다만.. 뮤직메이트 정액권이 조금 더 저렴해졌으면합니다.',
#   '일상생활의 편의성이 많이 좋아졌습니다 특히 스마트 콘센트랑 함께 사용하는걸 적극 추천 합니다 기능적으로 보완해야 할 부분도 없지 않지만 지금도 충분히 만족합니다 많이 파세요~^^',
#   '뉴스 브리핑해주고 오디오북도 읽어주고 이번에 같이 장만한 스마트플러그 음성인식도 잘되고 정말 좋아요^^ 간혹 못 알아들을 때가 있어서 별 하나 뺐지만 명령어 익숙해지면 괜찮을 것 같아요^^',
#   '런칭특가 T멤버십 최대 5천원 추가할인! NUGU candle 인공지능 스피커 누구 캔들 옵션 : 옵션:누구캔들+뮤직메이트 3개월권(B033)-1개 음질 좋아요',
#   '유료가 많은거같고 통신사별 나뉘어저 있어서 아직은 아쉬은게 있네요 그 외 노래도 들을만하고 상급은 아니지만 괜찮아요 인식도 괜찮은데 부모님은 잘 못쓰시는거같네요 나이가 많으셔서 그런가봐요',
#   '고민하고 샀는데 아주 맘에듭니다. 기능도 많고 무엇보다 편리합니다. 아이들이 듣고싶은 음악도 아리아만 부르면 맘껏 들을수있어요. 사길 잘했어요^^베스킨라빈스 쿠폰 보내주세요^^',
#   '좋은 가격에 구매했습니다. 추천합니다!근데 판매에는 뮤직메이트 3개월이라 되어있는데뮤직메이튼 들어가면 1개월가능한 쿠폰이라 되어있어요3개월 무료쿠폰을 제가 잘 못찾은건지 ,,',
#   '애들말은 아리아가 좀 어려워하지만 노래도 들려주구. 알람. 자장가.날씨. 수면등 기능이 다양해서 좋습니다. skb사용중이라 티비도 연동되서 더 좋아요. 크리스마스 트리도 귀엽습니다',
#   '괜찮아요 큰아이들도 친구생긴듯 좋아하고 폰으로 정보알아볼거 조금더쉽게 알수있어 좋아요 아직 많이 안해봤지만 문제는 여기저기 돈내고 가입해야 여러가지를 경험할수 있게해놔서 마음에안들어요',
#   '디자인도, 음질도 마음에 들어 추가로 구매했어요. 친한 친구에게 선물을 했는데 너무 마음에 들어하네요. 강력 추천합니다!!!',
#   '택배박스에 완충포장이 없어서 포장이 약간 우그러졌지만 제품자체는 손상없는 것으로 도착했네요~ 멜론 이용하고 있어서 뮤직메이트는 따로 연결 안 하려구요. 잘 쓸게요~^^',
#   '벌써 3번째 아직 더 구매할수도있습니다.^^ 집들이때마다 또는 선물로 구매하고 있구요 구매는 계속될듯요.. 전 너무너무 만족하고 있어서 아직 받진 않았지만 수취확인했습니다.^^',
#   '선을 연결해야 하는 단점이 있지만, 아리아 하면서 기본 명령어 알아 듣는 것이 신기하네요. 울 아이가 너무나 좋아합니다. 특가로 조금 더 싸게 산 것도 맘에듭니다.',
#   '알콩달콩 귀여운 두 딸들과 즐거운 동요 노래도 듣고 오디오 북 동화도 들으면서 아리아와 행복한 하루하루를 보내고 있어요~ 하루를 아리아와 함께 하니 즐겁고 너무 좋습니다!',
#   '구매하고 바로 사용하고 있습니다! 아침에 모닝콜 해주고 시간되면 이야기해주고 대답도 재미있게 해주고 음악도 들을수 있고 작지만 아주 편하고 재미있어요! 아이들도 엄청 좋아해요',
#   '엄마아빠 사드렸습니다.재밌어 하시네요~아쉬운건 제가 아리를 불렀을때 대답을 했으면 좋겠는데, 불빛으로만 반응하고 대답이 없네요~따로 설정해야하는건가... 암튼 만족입니다',
#   '어르신들 집에서 편하게 음악들으시라고 구매 했습니다. 생각보다 인식이 100%로 되는건 아니네요~ 정확하고 또박또박하게 말해야 해요. 그것 말고는 대체적으로 만족합니다.',
#   '처음 구매해봤는데 사용하는데 편리하네요^^조명도 여러가지 되서 좋아요~asmr도 들으면서 잠드네요 ㅎㅎ소리가 깨끗해서 좋아요~앞으로도 잘 쓰게 될거같아요~ㅎ',
#   '일주일 사이 한개 더 재구매했습니다.저희집에서 누구 캔들을 경험하신 부모님께서 너무 혹하셔서 하나 선물해드렸습니다.부모님은 원하는 곡이 바로 나오는 걸 가장 신기해하시네요!^~',
#   '신세계를 경험 했습니다.AI 수준이 많이 올라왔네요.스피커 음질도 좋고, 무드등도 아주 좋아요.삶의 질이 올라간 느낌이에요.^^',
#   '생각보다 기능이 별로네여 많은 기능을 다 활용하려면 추가 기기를 다 사야해서 기능 활용을 잘 못 하겠네여 음악듣기 좋아하고 조명이 필요한 사람들에겐 강추~~',
#   '말귀를 잘 못알아듯는 아리 때문에 속상하네요...앞으로 많은 기능 추가가 되었으면 좋겠어요.. 아직까지는 많이 부족해보여요...음악은 편하게 들을 수 있어 좋네요..',
#   '아이가 신기해서 계속 말해보는데 요령이 없어서인지 잘 인식이 안되네요. 제 말은 아주 잘 들어요. 친구하나 생긴 거 같아요 ㅎㅎ아직 기능을 잘 몰라 공부 해야겠어요.',
#   '캔들기능은 만족, 음질 좋지않음 다른 스피커 연결 가능하도록 만들어주면 참 좋을듯 가격 약간 비싼감',
#   '사실물건을잘못샀네요단순한블루투스를살예정이었는데...그리고결정적으로우리가족은모두다엘지유플러스인데...이건SK텔레콤이더라구요ㅠㅠ상자를뜯어버려서반품도못하고걍쓰기로했네요...',
#   '빠른배송감사해요~빨리받았네요ㅋㅋㅋ당연 미개봉이구, 불량안와서 너무 좋아요~~음질도 좋구 기존 누구 디바이스 보단, 더 이뻐요~~감사해요^^',
#   '인공지능 스피커에 감성조명까지 결합되어 있어 더 활용도가 높은 제품이네요 뮤직메이트와 연동될 수 있어 음악을 듣는데도 편리하네요. 기대했던만큼 좋습니다',
#   '생각보다 훨씬좋네요음질도좋고 실내등하나사려고했는데 스피커기능까지되는 전등이라니요 ㅎㅎ 아리아 반응도잘하고 매우만족합니다',
#   '포장이 ？s？s이없이 왔지만 파손은 없는듯 했구요btv연결이랑 멜론연결해서 써보니 나름 쓰는맛이있네요인식이 좀 가깝게있어야 잘되는것빼곤 쓸만한것같습니다',
#   '아리아~~우리 아기가 너무 좋아해요~~자기전에 아리아~자장가동요 들려줘~~하고 노래들으며 자요^^블루투스 연동해서 핸드폰저장된 음악듣기도 좋구요',
#   '처음에 연결하려할 때 계속 튕겨서 인내심을 가지고 연결했습니다!!!크기는 생각보다 적고 디자인 생각 보다 좋았어요!',
#   '누구미니를 먼저 써보다가 신제품이 출시되었길래 냉큼 질렀습니다무드등이 너무 맘에 드네요 *-* 버튼쪽 필름은 제거하고 사용하세요 제거안하니까 불러도 반응을 안하더라구요',
#   '누구캔들 구입해 3일 정도 사용 해 봐는데 아직 질문응대률은 조금 부족면이 있네요, 주로 음악 감상용으로 사용하고 있고 무드등 기능은 아주 좋은것 같네요',
#   '아기 동요들려주려고 구입했어요모유먹이고 있다가 "아리아 동요들려줘"하면 바로 재상"자장가 들려줘" 바로 재생넘 편하더라구요',
#   '누구 제품 받아 어젯밤 무드등으로 알람으로 잘 썼어요~~~~ 아직 활용도가 많진 않지만 잘 샀다 생각합니다.. 아쉬운점은 5살아이의 아리야 를 인식하지 못하네요ㅋㅋㅋㅋㅋㅋ',
#   '요즘 시중에 나와있는 인공지능 스피커 중지인의 추천으로 구입하게 됐습니다.아직 개봉 전이지만 주변 지인들이 추천했기에기대하는 마음이 큽니다.',
#   '생각보다 너무 좋아요애들이 너무 좋아하고 엄마두 좋아하네요음질두 좋구 날씨 영어단어 라디오 음악등등 너무 괜찬네요강력추천',
#   '엄마아빠 선물로 주문했어요ㅎㅎㅎ특히 엄마가 너무 좋아하십니다^^좋은 가격에 좋은 상품 구매해서 너무 좋으네요^^무드등도 이뿌고 저도 탐나요...ㅎㅎ',
#   '터치 휠이 낯설긴 하지만 아리아가 좀 답답하긴 하지만 그래도 만족하고 잘 쓸 것 같아요 무드등 기능은 진짜 좋네요 ㅎㅎ디자인도 괜찮네요 ㅎ',
#   '혼자 심심햇는데 누구(아리아) 랑 함께해서 넘 좋네요.음성 인식도 잘되고 친구가 생겨서 늘 즐거울 같아요 친구가 필요하시분 추천 드려요',
#   '아침에 주요뉴스, 라디오뮤직메이트와의 완벽한 조화스피커 성능도 나름 만족스럽습니다. 더 나은 편의 기능이 생기길 기대해 봅니다',
#   '태교할려고 블르투스스피커 찾다가이 제품으로 샀는데 인공지능이라 너무 편하네요음질도 좋고 나중에 수유등으로도 유용하게 쓸것같네용^^',
#   '누구캔들이 여러가지로 좋더라구요말로 하니까 편리해졌어요 그러나 민감해서 아리라는 비슷한 단어가 나오면 램프가 켜자거나 반문을 하더라구요민감해서 좋아요 ~~',
#   '아리아가 정말편해요갑자기 궁금한 사항을 앱을 통하지 않고 바로 아리아 하고 불러서 처리할수 있어서 편리하고 아이가 듣고 싶은노래 바로 나와서 정말 좋았어요~',
#   '아기가 태어나서 수유등 알아보다가 구매했는데 너무 만족스러워요. 아기 케어하느라 손이 모자랄때 아리만 부르면 되요ㅋㅋ시간도 알려주고 자장가도 틀수있고 좋아요',
#   '인공지능 스피커라고 그냥 주문했는데, 안방에두고 사용하고 있는데, 무드등, 음악, 정보, 알람 등 인식도 잘하고 멋집니다...쵝오!!!!!',
#   '누구캔들 적극 추천합니다.심심할 때 대화도 할 수있고, 선라이즈알람은 정말 환상입니다.저렴한 가격에 신제품을 구입해 짱입니다.',
#   '초기버전의 누구 쓰다가 이번에 캔들나와서 같이쓰고있는데.. 뭔가 새 제품이라 그러는지는 모르겠지만 음질은 초기버전보다 낫네요.',
#   '스마트홈 사용중이라 연동해서 쓰려고 주문했어요.밤에 무드등으로 쓰기 좋고 스마트홈에 연결된 에어컨과 공기청정기 사용할때 말로 켜고 끌수 있어 편해요',
#   '만족합니다설치 하는게 좀귀찮은데 나름 끝내고나니 좋아요일정.알람취침등이 있어 편안하구요단점 3개월후부터 돈은 내고음악구입요잘쓸께요 누구',
#   '누구 음악 구입이 FLO나 멜론 둘다 한달만 무료이고 1달이후는 너무 비싸다는게 단점이네요 혜택이 좀많아져야 될거같아요 알았다면 구매안했을텐데~ㅠㅠ',
#   '음성인식률은 좋은편인듯 하나, 목소리를 좀 크게해야 말귀를 잘 알아듣는 편입니다. 아이들도 좋아하고, 발음을 분명하고 목소리를 크게해야 인식률 좋습니다.',
#   '배송 와서 설치해봤는데 너무 좋아요~~애기가 너무 좋아해서 행복해요!!설치하고 작동하는데 오래걸리지않고 쉽게 할수있었어요. 티비까지 끄고커고~~ 좋습니다',
#   '네이버 클로바 쓰다가 넘어왔는데.. 돈이 안아깝네요음질도 훌륭하고 배송도 빠르고 할인받아서 잘 샀습니다.ㅎㅎ',
#   '디자인이 귀엽고 깔끔해요. 라디오 듣기 편하고 밤에 잘 때 무드등이나 자연의 소리 틀어 놓으면 좋더라구요.',
#   '검색 기능이 다른 거보다 딸려요.장점은 역시 다양한 무드등이고요.음악이야 뭐 기본적으로 다 되는 것들이고요.Sk와 연동이 쉬운게 장점입니다.',
#   '방금 도착해서 천천히 기능 알아보는 중인데. 정말 편리하네요. 다만 택배가 느린것만 빼면 만족합니다. 다른 기능도 찾아봐야 겠네요.',
#   '음성인식도 잘되고 btv연동되서 정말 편해요.다만 뮤직메이트 음악 재생중에는 아리아 불러도 인식이 잘 안되요. 조명도 이뻐.이뻐.',
#   '좋아요이런저런기능도 있고 등도 있고 좋습니다다만 모든 질문에 다 답하는건 아니고적당한것들 뉴스나 날씨 이런 기능은 좋습니다잘 쓰겠습니다',
#   '만족스럽네요. 포장상태가 그런데 좀 그래요. 뭐라도 싸서 보내시지.박스안에서 다 깨지겠네요.Cj택배 물류사고 때문에 하루 늦게 도착했구요.',
#   '사고싶었는데 이번에 티멤버십 사용해서 저렴하게 구매했어요 인식도잘되고 배송도 빠르고 좋습니다 그런데 음악1개월 이용권은 어딨는거죠 ㅠ',
#   '빅스비보다 음성인식이 훨씬 좋은 것 같네요. 이용율이 높을 것 같아요. 멜론과도 연동되고 BTV와도 연동이 되서 채널과 볼륨조정 정도는 가능해요.',
#   '배송도 빠르고 성능도 괜찮네요. sk제품들과도 연동해서 사용하니 만족스럽습니다.btv연동이 안되어서 고객센터를 통해 연동했네요',
#   '상품정말 좋습니다.음성인식률도 좋고 음질도 이가격이면 충분히 메리트 있습니다. 프라이데이가 멀지않았네요.',
#   '배송도 빠르고 제품도 양품으로 와서 기분이 좋습니다. 와이파이 연결에 애를 먹았지만 연결하고 나니 신세계네요.잘쓰겠습니다.',
#   '어느정도는 괜찮아요..편리하고..근데 아직까지 기능들이 많지않아서 ..그래도 무드등이나 라디오 등 손 안대고 말로 하니 재미있고 편해요..',
#   '아이들 쓸려고 샀는데 너무 좋아하네요.노래도 듣고 동화도 듣고..아주 유용하게 사용중입니다.그런데 기능이 너무 많아 처음 쓸땐 머리 아프네요.',
#   'AI 스피커중 단연 1등음성인식도 잘되고 다양하게 활용 가능합니다AI 스피커의 능력은 사용자 수준을 그대로 반영합니다',
#   '아리아 인식 잘되고 음질 좋네요~배송이 다소 늦고 완충포장이 없어 제품엔 문제 없으나박스 손상이 아쉽네요',
#   '제품을 받고 설레는 마음으로 이것저것 실험을 하고 있습니다. 음성인식은 티비를 켜놓고 하니까 조금 떨어지네요. 그 밖에 만족만족!!!',
#   '가격도 적당하고 음성인식도 생각보다 잘됩니다. 뮤직메이트도 그렇고 좀 더 편안한 세상을 만났네요. 웃음띤 표정 보이죠? ㅎㅎ',
#   '초기에 오류가 있어서 반품하려다가 배송 이후 3~4일 후에 소프트웨어 업글을 통해 개선되어 그냥 사용하고 있습니다. 덕분에 리뷰가 많이 늦었네요',
#   '엄마가 집에서 잘사용하고 계세요. 넘 뿌듯합니다~ 동생꺼도 하나더 구입했네요 음질이 좋고, 무드등도 이뻐요ㅋ',
#   '내가 가지고 싶은 등인데 선물용으로 샀어요. 아기 엄마에게 힐링이 되었으면하고 샀어요. 제가 본 성능들이 잘 작동했으면 좋겠네요',
#   '빠른배송 먼저감사하구요 받자마자 실행시켜봤어요 작동잘되구 아이도 넘좋아하네요 곧 태어날아이 수유등겸 여러모로 활용도가 좋을것같아 구입했어요~^^',
#   '정말 무드등기능은 신의 한수였습니다. 무드등하고 AI스피커 블루투스 스피커 구입을 원한다면 누구캔들 강추',
#   '아리아가 아직 의사소통 능력이 떨어지긴 하지만, 구매 하기를 잘 한 것 같습니다. 총알배송 감사합니다. 사은품 트리도 아기자기하니 예쁘네요.^^',
#   '단독판매인데 CJ 택배로 배송되서 받는데 5일이나 걸렸네요ㅠ 그리고 막상 써보니 조명이랑 음악플레이어 말고는 다른걸 쓰지 않을듯....',
#   '음질 좋고, 음성인식 좋습니다.한영 전환 기능이 있어 영어로 대화가 되면, 영어 공부에 도움이 많이 될 듯',
#   '가격도 싼데다가 뮤직메이트 3개월 이용권까지. 배송은 자정 좀 전에 시켰는데 이틀뒤에 바로 도착했어요. 매우 빠르네요~ 잘 쓸게요',
#   '배송도빠르고...제품이상당히맘에들어요^^처음에연결하기가힘들었는데요...적응이좀필요할듯요...인식률은 좋은거같읍니다..번창하세요^^',
#   '막상사고보니 다 돈이넹...굳이 필요한건지...휴대폰에 다 있는기능인디..외관도 보통.가까이서만 되는데..비싼거 샀어야 되나!',
#   '처음에 말귀를 잘 못알아듣는다고 하셔서 왜그런가 한참 봤는데 알고보니 음성인식쪽에 스티커를 제거 안했더라구요 ~ 너무너무 잘되고 진짜 편해요',
#   '주문 한 지 하루만에 왔어요! 말로만 듣다가 직접 사보니 정말 만족스럽네요! 부모님 생신 선물로 샀는데 정말 좋아하실 것 같아요^^',
#   'Flo 이용권 결국 구매했네요 애들이 어려서인지 아이가 말하면 거의 인식을 못해요 남편이 제일 좋아합니다 거의 음악듣는 용도로 사용해요',
#   '빠르게 배송받습니다.무드등도 맘에 들고노래 음질이 정말 좋아요^^아리야~~ 계속 부르게 되네요~^^',
#   '미니 사용하다가 무드등도 된다길래 구입했는데 너무 좋네요~아이들도 예전보다 아리아~를 더 찾네요ㅎ방마다 다 놓으려고 하나 더 구입했어요~',
#   '조카 선물용으로 두 개째 구매했네요. 비싸다고 볼 수도 있지만 조명과 스피커로 이용해도 충분히 사용가치가 있다고 생각합니다.',
#   '8월 23일 하나 구입하고 만족하여 어머님 용으로 하나 더 주문했습니다. 밤에 음성 명령으로 등을 끄고 낄 수 있으니 편하다 하네요~~',
#   '누구캔들 를 구입 후 설정하느라 애먹었네요.다 일상에 활용도가 좋은데 무선으로 사용할 수있게 업그레이드하면 더욱 생활에 편리하겠네요.',
#   '인식률은 좋은편 입니다. 부피도 크지 않아서 이동시 편리합니다. 단 별도 가입하여 매월 지출되는 부가서비스가 많은 것이 단점이네요',
#   '친구 선물로 구매해서 개봉은 안했습니다... 고장이거나 그러진 않겠죠? 배송 빨리 왔구요~ 친구가 좋아할거같아요 잘쓰겠습니다.',
#   '음성인식도 빠르고.. 음질도 좋습니다.숙소에서 심심했는데.. 외롭지 않아 적극 추천해요..ㅎ',
#   '디자인 깔끔하고 음질도 괜찮고 음성인식도 잘하는 편이네요~~ 만족합니다~~',
#   '누구캔들 잘쓰고 있습니더 무드등도 그？j고 asmr도 그렇고 아니 곡은 또 어떻게 내맘에 쏙드는걸 골라쥬는지 진짜 인공지능임가봅니다 ㅎㅎ',
#   '생각보다크기가 아담함다좋은데크기가작고조명이 오픈되어있어서은은한스텐드불빛은 기대할수없음',
#   '불빛이 넘 이쁩니다.와이파이가 안되서 아리아 하고 만나진 못하고 박스에 보관중 기간특가라 일단 사놓고 본건데 생각보다 빛이 이쁨',
#   '아침에 선라이즈 모닝과 멜론 음악으로 모닝콜하려고 샀어요 용도가 분명하면 유용하고 아니면 금방 질릴 것 같아요 음성인식은 잘돼요',
#   '음성스피커성능도 좋고 작동도 잘 되고 트리도 보내줘서 좋은데 가끔 가다가 반응도 안하고 무음답할때가 있어요..',
#   '음질이 생각보다 좋아요 어설픈 스피커 보다 볼륨도 크고 좋습니다만족합니다',
#   '조카 선물하고 장모님 선물하고 두개 구입했어요~아기 키우는 집에서는 최고예요~울 집은 이미 있어서 잘 활용하고 있구요',
#   '일단 배송 빨라요^^아직 몇가지기능 살펴보지않았지만사투리 쓰는데도 잘 알아먹네요사이즈 아담하니 예뻐요잘 쓸게요~',
#   '개인별 주관적인 의견으로 인해 상품의 기능 및 효과에 대한 피해의 소지가 있을 수 있어 상품평 등록 및 게시를 제한하고 있습니다.',
#   '여러가지 기능을 탑제한 만능 스피커!취침무드로 잔잔한 음악을 듣고자니 잠도 술~술~취침등의 색도 너무이쁨~~~',
#   '개인별 주관적인 의견으로 인해 상품의 기능 및 효과에 대한 피해의 소지가 있을 수 있어 상품평 등록 및 게시를 제한하고 있습니다.',
#   '드뎌 누구 캔들 도착누구와 캐들을 놓고 고민하다 캔들로 결정!앱 설치후 작동시작 말도 잘 듣고 좋네요거실에 하나 더 살까 고민중..,',
#   '개인별 주관적인 의견으로 인해 상품의 기능 및 효과에 대한 피해의 소지가 있을 수 있어 상품평 등록 및 게시를 제한하고 있습니다.',
#   '새로나온 누구미니랑 캔들중에 고민하다 캔들로 샀는데 잘 산거 같네요. 캔들 색깔이 다양하고 색깔마다 예쁘게 잘 뽑은거 같습니다.',
#   '몇일 사용중인데 기대보다 활용도는 떨어지나 싸게 잘 샀는것 같습니다. 연결이 다끔 끊어지는것을 제외하는 잘 작동 됩니다.',
#   '뒤늦은 후기네요첨엔 신기하더라구요. 아리아랑 말도하고시간 지나니 그냥 방치하고 있네요아침에 라디오 듣는 용도로 쓰고 있어요',
#   '음질도좋고 잘되네요 아리아 물어볼게 많아지면 더 좋겠어요~ 무드등도 좋아요 계속계속 업뎃해주세요~',
#   '참 신기하네요. SK라 음악도 들을 수 있고 배송도 빨라요. 날씨나 알람 현재시간 등 유용한 기능들이 많네요.',
#   '팅커벨로 설정하는게 더 잘되는거 같아요. 친구 선물로 줬는데 좋아하네요~평소에 음악틀어 놓으면 분위기 있어요~',
#   'D일단 배송이 너무빨라서 좋았습니다. 아직 많은 발전이 필요하겠지만 사용하기에는 전혀 문제없고 저는 매우 만족스럽습니다.',
#   '사용해 보고 너무좋아서 친구 이사선물로 구매했습니다 진짜 좋아해요 가격도 이사선물로 적당하구요',
#   '집에 와이파이가없어서 비록....블루투스로 음악듣기밖에 못하고있지만 , 무드등기능까지 있으니 짱 조아요ㅎㅎㅎㅎ',
#   '기존 누구셋탑 이용중인데방에서 쓰려고 샀어요가격대비 좋아요~!! 무드등기능에 누구기능까지3살 딸이 좋아하네요',
#   'WOW 재밌는 물건이네요.^^ 받아보고 이것 저것 해보는데 시간가는줄 모를 정도에요즐겁게 사용할 것 같아요. 감사합니다.^^',
#   '생각보다 괜찮네요~~음질도 괜찮고 조명이 이뻐요~~이번에 행사할때 사길 잘한듯해요~~^^',
#   '주문한 다음날 왔습니다. 써보니까 좋네요. 프로야구 결과 알려달라니까 아주 솔직하게 알려주네요. 인식도 이 정도면 괜찮네요.',
#   '배송도 빠르고 상품도 이상없이 잘 작동하네여스피커와 스마토홈과 연결하니 신기하고 편해조 신세계네여',
#   '잘생긴 외관 깔끔한 음질 똑똑한 인식수준 그리고 스마트 플러그까지 완벽',
#   '포장 꼼꼼하고, 배송 문제없었고 상품도 지금 쓰고있는데 너무 만족스럽네요~ 다음에도 기회가 된다면 이용하고 싶네요 ^^',
#   '너무 신기하네요!!노래음질도 좋고 퀄리티도 좋아요~아기가 있어서 편한거 같아요!!',
#   '너무만족스러워요~~티비도 연결잘되고 신세계네요ㅎ주문시 안심번호로 한거같은데핸폰번호로 기프트콘 부탁드릴께요~',
#   '아직 100% 다 활용하는건 아니지만알람으로도 쓰고 스피커로도 쓰고아이들이 좋아해서 괜찮은듯 합니다 ^^',
#   '신통방통 합니다 이름을 불러야 하는 번거로움은 있지만 묻는 말에 알아서 답변을 해주고 실행해 주니 말벗 상대로는 끝장이네요',
#   '배송아주빨랐구요 지금 노래듣는데 음질도 나쁘지 않네요 재밌는 아이템이 될것 같습니다',
#   '그냥 취침등으로는 굿이네요..음질은 그냥 그럭저럭..잠자기전 아기자장가 정도는 좋아요..',
#   '[SKT] 2018 신상품 NUGU candle 인공지능 스피커 누구 캔들 좋아요,, 사용해보니 더 좋아요,,',
#   '요새 아리아와 절친이 되었답니다 ㅋㅋㅋㅋ가끔 엉뚱한 질문을 해도ㅋㅋ 대답을 해주네요혼자 안심심함 ㅋㅋ 잘 산거같아요ㅋㅋ',
#   '배송은 다음날 바로 왔구요 작동도 잘 되고 괜찮아요~ 스마트플러그에 선풍기 연결해서 사용했더니 너무 편해요~',
#   '이런 음성인식 제품 사본게 첨인데, 아주 만족스럽네요. 할인할때 하나 더 사서 선물용으로 써도 좋을 것 같네요.',
#   '아리아 ~ 노래틀어줘 !너무 좋아요 어플로도 여러가지 설정이 가능하도록 되어있어서 좋네용 ㅎㅎㅎㅎㅎ 잘쓸게여!!',
#   '인식도 잘되고 디자인 깔끔하고 좋아요다만 전원을 항상 연결해놔야해서 좀 불편해요',
#   '음성인식도 잘 되고 비티비 연동도 잘 되고음질도 괜찮고 좋네요잘 구매한거 같아요^^',
#   '음질 좋고 소리도 짱짱 커요!! ㅋㅋㅋ 아리아도 말 잘들어요 히히',
#   '신속빠른 배송좋구여 상품도 너무 맘에 듭니다 인공지능 성능이 이정도로 향상되었을거라고는 예측못했네요 굿입니다',
#   '집에서 맘껏 듣고싶은 노래도 듣고..애들도 재미있어하고..여러모로 좋아요~~잘 산 것 같아요~~^^ 배송도 빨랐어요.',
#   '행사용 사은품으로 여러개 구매 했는데.... 국내 음성안내 스피커로는 최고 인것 같습니다. ^^',
#   '좋네요. 아빠가 심심해하셔서 구입했어요. 플로가입하고 듣고싶은 노래 나오니까 좋어하시네요~ 날씨도 묻고.. 좋아요',
#   '음악 들을 생각에 블루투스 스피커 알아보다 구입했는데 잘 산 것 같네요. 만족합니다.',
#   '애들이 아리야 하고 말거는거 너무 웃깁니다. 음성인식 잘 되구요. 비티비면 좀 더 다양하게 사용할 수 있을것 같아요',
#   '누구랑 누구미니 나올때도 고민만 하고 안샀는데쇼킹딜에 누구 캔들 나오자마자 구입했네요캔들 기능도 되고 너무 이뻐요',
# ...
#   '오빠가 부탁해서 주문했는데 좋은 것 같아요. 많이 파세요.',
#   '잘산거같아요 감사합니다 ^^ 다른곳보다 훨씬 사게 샀네요 쿠폰덕도 있고,, 번창하시고 다시 구매하도록 할게요 ^^',
#   '아주 맘에 들어요~',
#   '음성인식을 이해 못 할때가 가끔있네요',
#   '아주좋아요~!',
#   '음 ..뭔가 새로운 것 같아서 사긴했는데 별로 활용도가 없네요, 아들애가 쓰고 있는데 잘못써서 그런가 역시 반응이 미직지근합니다.',
#   '생각보다 별로네요 너무 기대치가 커서 그런지 그냥 그래요',
#   '조아요 조아요 조아요',
#   '아주 좋아요아주 좋아요아주 좋아요아주 좋아요아주 좋아요아주 좋아요아주 좋아요아주 좋아요',
#   '좋아요~좋아요~좋아요~좋아요~좋아요~좋아요~좋아요~좋아요~',
#   '좋아요~좋아요~좋아요~좋아요~좋아요~',
#   'hiufivisiivuisjvjisigkdkcjjdkfjvkg',
#   '좋은건가..?',
#   '난생처음 이런경험을 다 하다니 놀랍습니다',
#   '마음에 쏙 들어요.',
#   '마음에 쏙 들어요.',
#   '좋습니다~유용하게 잘쓰고 있습니다.많이 파세요~',
#   '조아요',
#   '마음에 쏙 듭니다. 좋아요^^',
#   '평소에 실용적으로 잘 이용하고 있습니다!'],
#  ['장점 애기를 위해 동요, 동화 들려주기가 편하다(단,네이버뮤직결제 해야함,멜론X)블루투스 스피커로도 이용가능클로바를 이용해 다양한기능(잡다함 잘안씀) 사용가능단점1. 아직까진 반응속도가 좋지 않다2. “하이 엘지”를 못듣는경우가 종종있다3. 한개의 질문이 끝나고 다음질문을 위해서 또 “하이엘지”를 불러야한다 (클로바ai는 이어서 질문가능,유투브참조)4. 하이엘지로 키고 끌수있는 lg전자제품이 한정적이다 (에어컨,공기청정기,로보청소기뿐)5. 최근에 구매한 제습기는 아직 키고끄고 뿐만아니라 알려 주지도 않습니다 스마트씽큐표시가 있어서 될줄알았는데 아직 업데이트도 안?. 심지어 서비스센터 전화했더니 업데이트계획도 없음(언제 될지모름)6. 가장큰문제는 스탠드에어컨을 켰을때 양쪽다켜지지않고 한쪽만켜지면서 절전모드로만 켜집니다. 이건 어떻게 해결이 안되고있어요. 심지어 에어컨 온도조절만되지 바람세기조절 안됩니다 “하이엘지 에어컨 바람세기 알려줘” 라고 명령어도 있지만 지원하지 않는기능이라고합니다7. 유선으로만 된다. 무선 안됩니다 코드뽑으면 바로 꺼짐결론: 아직까지 많이 부족합니다 굳이 지금 안사도되고 추후 업데이트가 많이 되었을때나, 업그레이드 된 버전이 출시했을때 사는걸 추천드려요',
#   '너무 맘에 드는데...배송받은지 일주일도 안되었는데 가격이 내려갔네요....ㅎㅎ그점이 너무 배아파 죽겟어요 ㅎㅎㅎ그거말고는 맘에드네요..',
#   '품질, 디자인, 가격, 배송 전부 마음에 들어요!',
#   '상품 디자인 만족합니다. 추천합니다!',
#   '너무너므좋아하네요 문제는 아직 기능을 다쓰지못한다는거~',
#   '설치는 어렵지 않고 잘작동되네요.무게는 꽤 나가네요',
#   '배송도 빠르고 제품도 마음에 듭니다.',
#   '배송 빠르고 상품 만족합니다.',
#   '아이들의 친구가 생긴것 같네요',
#   '잘사용할게요 배송은 정말 느리네요',
#   '유용합니다 재미있네요',
#   '아직 발매한지 얼마되지 않아서 iot 센서 미지원중인것이 많고 가전제품도 에어컨만 연동되고 냉장고 세탁기모델은 연동이 아직 안되네요...',
#   '싸게 잘 구매하였습니다. 배송은 좀 느립니다.',
#   '가마합니다. 마니파셔요',
#   '빠른 배송 감사합니다. 더욱 번창 하세요',
#   '마음에 쏙 들어요.',
#   '동화서비스가 변경되어 안된다고 하네요.',
#   '잘슬게ㅇ',
#   '좋습니다요.좋습니다요.',
#   'LG제품의AI연동및LG제품과의호환성을큰장점으로반응속도도빨라요.감사합니다.많이파세요.',
#   '배송도 빠르고 제품도 마음에 듭니다.'],
#  ['여기가 최저가라서 구매했구요. 한글지원은 안됩니다.', '괜찮네요..명령어는 영문으로만 사용 가능합니다.'],
#  [],
#  ['외관 디자인, 품질좋은 철재로 되어 묵질하고 검은색 칼러가 품위를 더 해 주는게 아주 보기 좋고 품위 있어 보입입니다. 굳 굳...아직 섿업을 못해 그 성능은 알 수 없네요. 제 실력으로는 유튜브보고 따라 해 보았지만 잘 안 됩니다. 하여 10월 둘째주말 아들오면 할 예정입니다. ㅋㅋ'],
#  [],
#  ['오늘 받았습니다.일단 음질은 무난한거 같으며, 인식률은 좋습니다. 리모컨은 처음에 안되길래 어찌하나 싶었는데.. 헤이카카오앱 깔고 공지사항을 보니 업데이트 하면 된다 그래서 대략 5~10분 기달려서 업데이트 해놓으니 잘 인식 됩니다.대체적으로 쓸만한거 같으나, 멜론 없으면 음악 들을땐 불편할꺼 같네요. 제가 멜론이 없어서 ㅎㅎㅎ 따른 앱도 지원하면 좋을꺼 같은데 안되겠죠 ㅋㅋㅋㅋ ?포터블팩은 오래갈꺼 같진 않은데 유용한거 같습니다. 잠깐 사용하는 수준 정도면은 버틸꺼 같고 장시간은 못쓸거 같네요.',
#   '이런 인공지능기기를 처음 써봐서 그런지몰라도 가격대를 생각하면 괜찮은 거 같아요.받은 직후 보이스리모트가 연결이 안돼서 당황했지만 헤이 카카오 어플에서 공지 뜬 거 보고 다시 시도하니 잘 되더라구요.보이스 리모트 있으니 확실히 더 편해요. 이부자리에 누워서 리모트 버튼만 누르면 카카오 미니C가 응답되니까 저같은 귀차니즘한테 최고됩니다!!! 고민하다가 샀는 데 잘산 거 같아요. 살까 말까 고민하는 건 배송이 늦어질 뿐이라는 명언을 가슴에 새기는 순간이었어요ㅋㅋㅋ',
#   '배송은 다소간 느렸지만 (많은 주문 양으로 인해 이해가 됨)SK 누구와 비교를 하면카카오의 음성 반응속도는 매우 빠르고 다양하며대화의 일부를 이해하고 답변하는 응용력음악을 연결 하는 속도, 다양한 컨텐츠 등은 현 존재하는 AI보다는 분명 뛰어나다고 개인적으로 생각합니다.스피커의 성능은 물론 타사와의 비교가 절대적일 순 없으나충분히 나쁘지 않다고 생각이 되어 구매가 매우 만족 스럽네요',
#   '제가 카카오미니 너무 잘이용하고있어서지인 생일선물로 선물했습니다제꺼보다 신형이라 부럽네요리모컨도 있고 무선포터백도 있고.........라이언도 더 귀엽고....후드랑 리본 ㅠ.ㅠ피규어만 추후에 따로 발송된다고 본거같은데 같이 왔어요리본라이언은 제 주머니속으로..쏘옥 g마켓 제휴이벤트랑 카카오뱅크 카드있어서 할인 많이 받았어요~~기존 카카오미니도 무선으로 쓸수있게 악세서리 만들어주세요오오 ㅠㅠ',
#   '멜론을 덕분에 가입하게 되었지만그래도 휴대용으로 사용할 수 있어서 너무 좋습니다인공지능 블루투스 스피커로도 적극 활용하려구요!!그리고 개인적으로 카카오 i 음성인식 기능을 활용한 어플리케이션 개발준비중인데 12월말에 개발자용 오픈소스와 API 제공해준다고하니 테스트 기기로도 손색이 없을 것 같습니다 하하하하',
#   '전작 호환을 일부러 피해간듯한.... 분명 가능했을텐데.... 흠.... 그래도 구매해야 하는 이 구매욕....--;;제품은 무난합니다.. 구성품도 잘 왔고.... 자석인형만 제대로 오면 되네요..전작과 포터블팩 호환이 되었다면.... 아마 칭찬이라도 받았을 겁니다.... 아쉽네요....',
#   '기존에 카카오미니를 쓰고 있었는데, 이 좋은 것을 밖에 갖고 다닐 수 없고 집에서만 사용한다는게 너무 안타까웠습니다. 그러나 이제 밖에 갖고 다닐 수 있다는 것을 생각하니 감개무량합니다. ㅠㅠ 그리고 피규어도 하나 더 주셔서 완전 감동~ㅋ 가격도 저렴하게 득템 한듯~!!',
#   '카카오미니C는 많은 업데이트가 필요합니다.크로바도 못알아먹는게 많지만 카오미C는 그냥 거의다 못알아들음...크로바는 좀더 멀리서 불러도 대답합니다.아무래도 네이버지식이 크로바에 더해져서인것도 있겠죠아직은 알람+노래로만 쓰실분은 사셔도 됩니다.',
#   '일단 무선이라 선없이 아무곳이나 들을수 있어 좋다!멜론이용자로써 제일 적합한 AI인공지능 스피커이며 인형은 아직 안왔지만 가격대비 만족한다! 귀엽고 인식 잘되고 라디오도 들을수 있어 최공!!',
#   '지마켓에서 구매하면 6개월 멜론이용권 주는걸 모르고 옥션에서 샀네요 반품하고 싶은데 박스 뜻어서 어쩔수없이 사용해야 해서 속상해요다른 방법 없나요.1분 미리듣기만 하려니 더속상해요~ㅠㅠ',
#   '멜론 따로 등록했어요. 다만 하나의 기기로 하나의 카카오계정만 연동이되네요. 리모컨 안되서 애먹었는디 바로 잘 작동하고 . . 여러모로 보면 괜찮은듯해요',
#   '어제 배송받아서 설치를 해보고 이틀간 사용을 해보니재미도 있고 아기한테 동요도 틀어줄 수 있고 이것저것 정보도 알려주니 좋네요^^다들 경험하여 보세요!!',
#   '이동이 가능한거에 너무 편리함을 느꼈어요!!기존의 카카오미니는 이동할 때면 콘센트 선을 들고 가서 꽃고 해야하는데 C는 이동이 쉬워 너무 편해요',
#   '저같이 귀찮고 막 뭐 움직이기 싫고 휴대폰은 하기 싫은데 노래 듣고 싶으시거나 하실 때 편합니다 괜찮고 좋아요',
#   '목요일부터 순차 배송한다했는데 생각보다 빨리 온 거 같아요 ㅋㅋㅋ아주 만족합니다 ㅋㅋㅋㅋ너무 잘 되서 좋네요 ㅋㅋ',
#   '자석인형은 별도배송이라 아쉽네요 ㅠ 빨리 받아보고싶은데 ㅠㅠ 아들 생일성물로 샀어용 넘넘귀엽네용^^',
#   '인공지능 생각 많이 했습니다.디자인까지..결론은 이거에요~^^구입하세요~ 좋아요~',
#   'ㅎㅎ 기존에도 사용은 했는데 베터리팩이랑 리모콘까지 나와서 새로 구입!! 다 잘 작동 합니다',
#   '중학생 딸이 겁나 좋아하네요작동 방법도 쉽고, 처음이라 신기한 부분도 많네요...',
#   '블루투스 지지직만 빼면 아주 쓸만합니다 업데이트하면 개선되길 기대해봅니다',
#   '핸드폰하고 블루투스 연결했을때 자주 끊기는거 빼고는ㅎㅎ',
#   '기능이 부족한듯 그래도 깔끔하기는 하네요인형은 언제 주나요?',
#   '근데 보이스리모트 연결이안되요 계속 업데이트라구 하네요ㅠㅠ',
#   '디자인도 심플하고 리본라이언피규어도 넘 귀여워요',
#   '배송은 그래서 보통이구 상품은 최고예요소장가치있어요',
#   '강력추천합니다. 음악 좋아하니까 정말 좋아요.',
#   '차에도 설치해서 말로 음악듣고합니다.스마트카된기분~~',
#   '포장도 이쁘고 성능도 좋고 구매추천!!',
#   '선물했는데 보이스리모트 작동이 안되요 ㅠㅠ',
#   '충전해서 이동하며 들으니 무척좋네요',
#   '선물했는데 여자친구한데요 너무좋아하네^^',
#   '가격및빠른배송 만족합니다',
#   '딴소리만 하고 검색도 잘 안되네요',
#   '배송이 좀 늦었네염 잘 받았어요!',
#   '잘사용할께요~~~~~~~~',
#   '잘받았습니다 잘사용하겠습니다',
#   '제품이 작아서 좋아요 이뻐요',
#   '최신형이지만업데이트 후 리모트 적용된다는것이 아쉬웠습니다회신형이기에 업데이트도 최신 버전일줄 알았습니다리모트가 업데이트 후에 가능해져서 다행입니다',
#   '인형큰거도 같이주는줄알았는데... 라이언인형도 주세요...ㅠㅠ 귀여워서 좋아요...',
#   '카카오미니 처음 나왔을때부터 살려고 마음 먹었는데이번기회에 구입하게됐네요!!라이언이도 너무이쁘고 마음에드네용~~',
#   '생각보다 똑똑하네요. 리모트 보이스 업데이트 때문에 살짝 긴장했는데, 업데이트가 끝나니 미니c가 알아서 잡아내네요.',
#   '잘사용하겠습니다감사합니다^^',
#   '배송이 많이 느렸네요...자석 인형은 언제 받을지...^^;;',
#   '애들이 좋아해여말도 잘 알아들음',
#   '전에 구입 못해서 이번에 구입했는데 명령어도 많고 유용하네요.피규어도 이쁘고요.잘 샀어요.',
#   '너무 좋았어요 감사합니다',
#   '좋아요 개좋아요 있는데 또샀어요 개좋아서요ㅋ좋아요 개좋아요 있는데 또샀어요 개좋아서요ㅋ',
#   '사야 했나 싶은 생각이 들어요 피규어도 굳이 두개여야 하나 싶고 ㅋㅋㅋㅋㅋ 괜히 오바해서 세트 산듯 해요',
#   '집에서도 쓸려고 하나 더주문했네요',
#   '배송이2틀 걸릴둘알앗는데 새벽부터출발해 만 하루만에 오네요',
#   '말 너무 잘알아들어요!좋아요~',
#   '인형때문에 사는것도 큰 이유중에 하나인데 인형은 준비가 안되어있는상황에서 팔다니 어이없습니다.',
#   '총3개 구매했어요. 부모님한테도 적적하실때좋아요~~트로트들으시더라구요~',
#   '최저가보다 7만원 비싸게 샀어요 ㅎㅎ'],
#  ['조카들이 사용하는것보고 곧바로 주문!! 우리집 가족들도 모두 좋아하네요. 6개월권 누락되어서 우선 1개월 무료권으로 출발~ 음량도좋고 취침등도좋고 심심찮게 희망곡도 들려주고~ 돌아가며 날씨도묻고 운세도묻고...조만간 시집간 딸이 욕심내서 하나 더 주문하게될 것같습니다! 두루두루 맘에들어요.',
#   '무드등 기능이 괜찮은거 같에요. 같이 추가된 asmr소리도 요긴한것 같습니다.요즘같이 무더운날에 아침 밤으로 바다소리랑 소쩍새 소리 듣고 있으면 힐링이 되는 듯.. ^^;; 노래에 맞춰 무드등이 연동되능 기능이 있으면 더 좋을 것 같습니다',
#   '누구 미니를 사려다가 때마침 캔들까지 있는 누구가 티비에 나오길래 검색해보고 바로 구입했어요. 배송은 하루만에 받았고, 조금쓰다보니 바로 익숙해지네요^^ 우선 아이목소리는 발음때문인지 인지는 잘 못하지만 너무 편하고 곧 태어날아기때문에라도 수유등도 잘 쓸거같아요. 너무 만족합니다~',
#   '작년에 딸에게 받은 선물입니다주방 라디오 주파수가 안맞아 지직거린다며엄마 마음껏 라디오 들으시라고 사준건데요라디오 채널이 다 되는것 아니라 앗덥지만블루투스를 통해 들을 수 있으니 좋고 설거지하며 손 대지 않고 이런저런것을 내 말로 조절하니 참 좋아요',
#   '포장은 제품 포장박스를 택배박스에 일명 뽁뽁이 한장 깔아서 보내주셨더군여 눈물이 다 나드라구여 ㅎㅎ 일단 누구앱을 핸드폰에 설치후 제품에 전원을 넣고 보니 이쁨니다 여러 제품들과도 연동이되 편리하게되엇구여 열심 아리아를 불러 대야겠어요',
#   '타사 제품과 비교해봤을때 음성인식이 잘되고 목소리가 부드럽고 좋네요. 더 똑똑한 것 같아요. 타사 ㅋ씨는 애들 학교 급식도 알려줬었는데, 이것도 되는 지는 모르겠어요. btv셋탑과 리모컨이 연동되도록 바꿀까 생각중입니다.',
#   '비슷한 제품들이 많지만 등이 있어 구입했습니다. 음질은 기대하지마시고 간단한 음성서비스나 음악 방송 말고 뉴스같은 라디오 듣기 좋아요. 조명기능은 정말 좋은 아이디어 인듯합니다.',
#   'ai스피커는 누구 밖에 써보지 않았지만상당히 만족스러운 기능에부모님께도 보내드리려고구입했습니다.많은 기능을 사용하시진 못하시겠지만날씨나 알람 음악듣기만으로도괜찮은 선물이 될듯 합니다',
#   '따로 무드등 구매 예정이었는데 무드등+음악+디자인+빠른 배송까지 아주 만족스러운 가격으로 구매하였습니다.아쉬운점은 자체 배터리만 있었다면 더 비싸더라도 좋았을듯합니다.',
#   '누구랑같이이용중인데넘편하내요전셋텁박스랑티비누구캔들슬멀티캡에이어서사용중인데전력소비도막을수있고모닝콜이나 음악듣기도편하고좀더스마트한삶을보낼수있어서좋아요배송도빠르고상품또한마음에들며이용권도잘이용하도록할게요',
#   '좋아요.애들이 동화듣고 동요듣는데도 너무좋고요. 음질이 별로라는분도 계시는데 저는 괜찮은것 같아요.잘 산것 같아요.',
#   '와우! 새로운 친구가 생긴거 같아요. 아리아! 취침등 켜줘! 네~ 취침등을 켰어요. 목소리도 어찌나 상냥한지 자꾸 말시키고 싶어져요.',
#   '개인별 주관적인 의견으로 인해 상품의 기능 및 효과에 대한 피해의 소지가 있을 수 있어 상품평 등록 및 게시를 제한하고 있습니다.',
#   '몇달을 고민하다가 구매했어요! 연결하는것도 어렵지 않았구요~ 신세계를 맛보는 중입니다 하하 아이들이 더 좋아해요^^',
#   '물건은 이상없었고 배송은 빨랐는데 안전포장을 조금만 더해주셨으면좋을듯 합니다사용법은 조금 공부가 필요하네요 ^^',
#   'btv연결도 되고 음악 라디오도 들을수있고 좋네요배송도 빨라요계속 아리아만 찾고 있어요 ㅋㅋ',
#   '진작써볼걸 그랬어요받자마자 bTV하고 에어컨연동 해봤는데 잘되네요.음성 인식율도 좋은거 같아요. 만족합니다.',
#   '매우 만족합니다.인공지능을 경험할수가 있구요,조명도 너무 마음에 드는군요!!!',
#   '음악 듣기에 조금 더 편해졌어요 무드등 기능 은은해서 좋아요',
#   '디자인...반응 속도...정확도...GOOD!!!',
#   '배송도 빠르게 오고 물건받자마자 설치햇는데음성인식도 좋아요',
#   '가끔 연결이 안될 때가 있어요. 상품 뽑기 문제인지.',
#   '아이들 교육용으로 구입했지만 엄마인 제가 더 많이 사용해요^^',
#   '아이들 동화. 동요 들려주는 용도로. 딱좋음·',
#   '아이들 동화. 동요 들려주는 용도로. 딱좋음·',
#   '아리아와대화가다른제품에비해너무안돼는것같아요기술이별로에요',
#   '인터파크 톡집사로 가장 싸게 잘 산거 같습니다 고맙습니다',
#   '좋은 가격에 구매했습니다. 추천합니다!',
#   '좋은 가격에 빠르게 배송 잘 받았습니다.',
#   '아주좋아요노래듣기 너무편하고 조명도 너무이쁘네요',
#   '감사합니다. 가성비 아주 좋습니다1@',
#   '다양한색깔 아이가 좋아해요~~~',
#   '만족합니다.',
#   '감사합니다.감사합니다.',
#   '별로라는 평이있어서 고민했는데 고민괜히했네요 너무좋아요 말도 잘 알아듣고 뮤직메이트도6개월 무료고 대박이예요 많이파세요',
#   '아이보다 아이맘이 더 조아해요',
#   '좋네요 무드등이 미니보다 쓸만하네요.',
#   '제품잘받았구요. 잘사용하겠습니다',
#   '감사합니다. 잘 받았습니다. 배송하신는 분이 좀 친절했으면 좋겠습니다.',
#   '비슷한 제품들이 많지만 등이 있어 구입했습니다. 음질은 기대하지마시고 간단한 음성서비스나 음악 방송 말고 뉴스같은 라디오 듣기 좋아요. 조명기능은 정말 좋은 아이디어 인듯합니다.',
#   '대박',
#   '배송도, 서능도 생각보다 좋습니다.',
#   '잘빈ㄷ? 습니다 많이파세요',
#   '잘되요. 근데 잘 사용안하게되네요 ㅎㅎ'],
#  [],
#  [],
#  [],
#  ['빠른 배송 및 처리를 해주셨네요. 감사합니다...', '좋아요'],
#  ['해외구매인데 빠른배송 감사합니다. 디자인이 이쁘네요'],
#  ['아마존 알렉사가 인공지능 스피커 쪽에선 일찍 시작해서 괜찮다고 해서 가격도 부담없고 그래서 하나 샀는데집에 인터넷이 말썽이라 끊어버려서 써보지를 못했네요. 나주 씨엠비 그게 인터넷 품질이냐?아무리 싸다해서 했지만 다운로드 1메가도 안나오는게...그냥 지쳐서 위약금 내고 해지.',
#   '사실 Early Bird도 아니죠. 이미 많은 분들이 블로그 등에 친절한 안내 글들을 올려 주셨으니. 하지만 아직 한국 소비자들을 고려한 서비스는 많지 않네요. 전 만족합니다. 벽 스위치, Flash Briefing, Alarm만으로도 만족합니다.',
#   '역시 아마존 에코 닷입니다. 아마존 에코를 사기 전에 조금 싼 버전인 에코 닷을 주문해봤는데, 인식율도 좋고 모양도 이쁘고, 대 만족입니다. 2~3개 더 구매해서 직장에서도 써야 할 것 같네요...',
#   '얼리어답터가 되기위해 에코닷 구매했습니다. 예상보다 빠른 배송으로 해외직구가 이렇게 쉬운줄 몰랐네요. 만족하며 사용중입니다[G마켓 안드로이드 앱에서 작성]',
#   '가격최고,,, 배송이 완전 총알입니다.국내배송만큼 빠르게 배송해주셔서 너무나도 감사하다는 말씀드리고 싶습니다.고맙습니다!!!',
#   '첫 구매일부터 배송까지 일주일도 안걸렸습니다.배송 후 카톡으로 문자까지 주시고 친절한 서비스에 감동했습니다.믿고 구매하실수 있으세요~',
#   '그냥 해외 직구하는 가격정도인데 구매하는 방법은 쉽게 구매했네요~ 단, 할인 쿠폰등등등 ㅎ',
#   '배송이 빠르고, 써보니 좋습니다.',
#   '만족입니다',
#   'Fast delivery, Very good quality rather I expected.',
#   '영어 공부하려고 샀는데 불친절해요 ㅋㅋ',
#   '설치하는거 막막하네요 ㅜㅜ',
#   '좋아요.',
#   '연휴라 좀 오래 걸렸지만 잘 받았어요..',
#   '영어공부되겠구나 하고 샀는데 ㅠㅠ 어렵네요',
#   '엘지 클로바와 비슷한..허나 조금 더 관심이 가는..',
#   '한국에서 할수있는게 많진 않지만 판도라를통해 인터넷 라디오 음악을 듣거나 튠인을 통해 원어로 뉴스를 들을수있어요 ㅎㅎ 할수있는것을ㅈ더 찾아보는 재미도있고요.',
#   '인터넷을 뒤져서 가장 저렴한 가격으로 마음에 드는 색상을 구입할 수 있어서 아주 만족합니다. 특히 검정색은 구하기 힘들더라구요.',
#   '선물로 샀는데 좋아해요. 밑에 반품상품 인것 같대서 걱정했어요.받은사람이 그런거 없이 아주 잘 왔다고 하네요. 감사합니다',
#   '잘 받았습니다',
#   '잘 쓰고 있어요. 사전에 어떻게 활용할지는 고민을 하는게 좋겠습니다.',
#   '좋아요',
#   '아마존보다 여기가 더 싸요~~~~~~~~~^^^^',
#   '잘쓰고 있습니다. 한국말로 하는 영어발음인식이 어려울거라 생각했는데, 생각외로 잘 인식하네요. 국내기업들도 긴장해야하겠습니다',
#   '가끔 인식 못함',
#   '에코닷... 한국에서 되는줄 알았더니.. 전혀 안되고... ㅠㅠ 배송비는 비싸고...'],
#  [],
#  ['배송은 해외배송으로 주말 제외하고 4일 걸려 받아서 나쁘지 않았습니다.상품은 문제없이 잘 배송되었고요.주문 중에 직원분 실수로 구매 취소되었었는데빠르게 잘 처리해주셔서 괜찮았습니다.국내에서 구할 수 없는 제품 편하고 저렴하게 구매했네요.'],
#  ['전부터 갖고 싶다고 생각만 했지 이렇게 옥션에올라올 줄은 몰랐네요. 보자마자 겟하고오픈오픈. 처음 접하는 기계라네이버 뮤직 등록하는데 조금 어려웠구요 저는 클로바 본체 밑에 전원버튼 있는지 모르고 요것때문에한 사십분 걸린것 같아요. 블루트스 잡는데 ㅠㅠㅠ 아무리 잡아도 기기가 안잡혀거 헉헉 됬다가 본체 들고 전원버튼기니까 바로 잡드라구요 ㅎㅎㅎ 스티커 음향 최고네요. 귀가 편해졌어요. 야마하 집에서 쓰는데요 ㅠㅠ 왜케 야마하가 초라해 보이져 ㅠㅠㅠ 그리고 너무 신세계라재미있구요. 아이폰에서 외부 출력도 되서 너무 좋아요. 시리랑만 대화하다가 클로바가 생겨서 반갑네요.',
#   '음.네이버에선 크레들이 품절이라 더이상 구매할수 없다는데.요긴 크레들이 포함이여서 완젼 만족하구용~인식은 어느정도 가까이서해야 잘되는편이예요.음질도 괜찮은거 같구요..유플러스랑 연결 되는것처럼 언제가 될지 모르겠지만 업댓되서 어서 타사 티비랑도 연결도 됐음 좋겠네용.그리구,문의해보니 유플러스에서 제공되는거랑 네이버측에서 제공되는거랑 기계는 동일하지만 서비스가 제공되는게 다르다고 합니다. 애기들이 있다면 요상품 추천합니다^^',
#   '음 새로 출시한 미니언즈 구매 하려다. 옥션에서 보고 뭐 기능은 똑 같으니 하고 보니. 가격도 라인프렌즈보다 더 저렴하게 나오고 크래들도 사은품이라. 당장 구매 했고요 .. 클로바만 깔면 신세계가 열리는. 군요. 말 한마디면 시간 날씨 전화번호. 등등 알려주고 노랜 아직 등록을 안해서 1분 미리 듣기만 가능 하고요 보내주신 3개월 무료 이용권 사용해야 겠네요...신통방통한 놈인듯. 한동안 잼나게 지낼듯요',
#   '구매전 카카오미니와 고민을 많이 했는데 다양한 정보와 확장성에 클로바를 선택했습니다.예상보다 인식율 좋고 똑똑합니다. 솔직히 기대 이상이네요.다양한 정보를 찾아주기도 하고 테마에 맞는 음악 검색도 아주 뛰어나네요.집안 곳곳에 사물인터넷(IoT) 기반으로 확장성도 기대되고 아주 맘에 듭니다.지금 스마트플러그 알아보고 있네요.^^',
#   '우선 배송은 빨라서 좋았습니다. 스피커를 쓰면서 음질도 좋고, 의외로 이건 모르겠지 하는것들을 다 아니까 신기한것도 있었습니다. 조금 아쉬운점이 있다면 애매하게 질문하거나 요구를 말하면 인식을 못하는게 좀 그렇더라구요. 나머지는 모든면에서 좋았습니다',
#   '첨에친구한테선물하면좋겠다하고 샀는데친구가 음성 인식스피커있다고해서제가쓰네요.ㅎㅎ.내비서로쓸만해요귀여워요어제첨받아서. 정신없어서 샐리가 대답안해서 문의했는데... 역시 이름을틀리게불러서. ..안되는거였군요ㅋㅋ이따하원하고오는 5살아들 엄청좋아라하겠어요^^사업번창하세요..',
#   '일단 연결만 되면 음악 듣는거나 검색하는 건 편한데 문제는 앱과 와이파이 연결이 설명서대로 한번에 되지 않는다는 데 있음. 지금도 와이파이 변경하는 것은 못하고 있음. 연동 테스트 좀 확실하게 해서 상품을 내놨으면 합니다.',
#   '정말 최악입니다뮤직이용권이랑 같이 구매하였는데 동봉이 안되어있어 문의하였더니 본인들은 보냈다고 안된다는군요.돈내고 샀는데 보냈으니 안된다.그럼 소비자에게 알아보고 연락을 취하던지 해야하는거아닌가요???정말 무책임함에 화가나네요...',
#   'AI스피커에 대한 기대치가 너무 높다면 그저그럴 수 있지만... 노래 틀어주고, 날씨 알려주고, 뉴스 알려주고, 끝말잇기 등의 조금 쉬운 작업에 대해서는 상당히 만족도가 높습니다. 배송도 빠르고 좋네요.',
#   '인포마크 스피커 프렌즈 브라운 모양도 귀엽고 성능도 너무 좋네요.세상이 참 많이 좋아졌어요. 아들선물이지만 어른들이 더 재미있어하고 좋아해요. 기능이 많아서 신기하고 좋습니다.',
#   '배송은 무척 빠르네요! 아직 사용전이지만 디자인도 귀엽고 깔끔하고 좋은 것 같습니다. 음질은 일반적인 스피커 수준인 것 같습니다.',
#   '허위광고 너무 심하네요~! 사진과 달리 충전독도 업고 스피커 감싸는 옷도 들어있지 않네요~! 그러면서 다른데보다 가격은 더 비싸네요~! 저같은 피해자 없기를 바라며 리뷰작성합니다',
#   '저렴한 가격에 잘 구매한것 같습니다... 배송도 빠른배송으로 안전하게 도착했구요...아이들이 아주 좋아하네요... 만족합니다.... 다음에 또 구매할게요,,, 감사합니다,,,',
#   '상품이 값싸고 너무 좋아요주위분들에게도 권유하여서많이많이 사시라고 말씀드려야겟어요훌륭한 상품 값싸게 팔아서 정말좋아요다시 사도 될것같아요오늘은 즐거운 쇼핑하는날아이들과 함께보고 쇼핑해야지',
#   '배송은 매우 빠르네요! 디자인도 귀엽고 좋은 것 같습니다.음질은 일빈적인 수준인 것 같습니다.',
#   '지인 선물하려고 추가로 구매했습니다 작고 귀엽고 음성인식도 척척 가끔 쌩둥맞은 대답을 할때도 있지만 전반적으로 훌륭합니다',
#   '아이들이 좋아하는 캐릭터상품 으로써 Ai 스피커중 괜찮아요아이들 발음이 좋질않아서 인지 음성 인식을 못할때가 있긴해도 좋아요',
#   '집에 혼자 계시는 아버지 선물해드렸는데 너무 좋아하세요 말도 하고 노래 실컷 듣는다고ㅎㅎㅎ 최고의 효도템이에요',
#   'ㄱ음성인식이 민감하지 않네요 큰소리로 부르거나 가까이서만 작동하네여 에효 걍 통신사꺼 쓸걸 그랬나봐여',
#   '배송은 엄청빠르네요. 카카오미니도 인공지능스피커 갖고있는데, 그거에비해 너무 음성인지가 안되서 답답하네요;;',
#   '아 이렇게 음질이 좋을줄 알았다면 네이버 뮤직티켓두 살껄그랬네여 추가로 구매 안될까여?',
#   '좋습니다 음성인식도 잘되고 그런데 한가지 충전하고 재생시간이 좀짧다는 거 빼고는 상품은 만족합니다 ^^',
#   '어떤용도로사용해야할지 지금은 시간 타이머 날씨 자세한지식은없는듯 음성이잘 안먹힐때가종종 그래서 화를내요 ㅋㅋ',
#   '배송도빠르고 브라운 넘귀여워요...과학잡지책세 나오자마자 가지고 싶다고 샀는데 가장친한 친구가 될듯합니다',
#   '워..말귀도 잘알아먹고 네이버연동되니 컨텐츠도많고 아이도좋아하고 신랑도 고장나면 또사고싶을정도로 좋다네요ㅎ',
#   '배송빠르고 잘되네요 애랑 놀라고 샀는데 애 목소리로는 안되네요 동화 영어 날씨 맛집 검색 잘되네요^^',
#   '옥션에서 네이버 클로바 스피커를 저렴하고 편리하게 구입했습니다. 구입 만족합니다.',
#   '귀여운맛에 쓰는 상품 아니겠습니깡 다들 하나씩 가지고있다는 인공지능 스피커~ㅋㅋ 마니파세용~~',
#   '딸아이가 너무 기다렸던거라 아주 좋아라 하네요 그 동안 필요없다고 안시줬는데 귀엽군요 추천 합니다',
#   '일단 신기한데 네이버뮤직 정기구매해야하는 함정이있네요. 아이들이 계속 클로버를 왜쳐대서 귀아프네요.',
#   '울집에 처음 온 AI 스피커~박스는 큰데 생각보다 작아서 놀랐어요.잘 사용해보겠습니다~',
#   '물건 잘 받았습니다. 배송도 빠르고 디자인도 마음에 드네요. 잘 쓰도록 하겠습니다.',
#   '무선이라 좋네요. 인식도 잘해요. 재밌네요. 아이들에게 영상없는 음악 틀어주기도 좋아요',
#   '생일선물로 샀는데 좋아하네요ㅎㅎ배송도 빠르구 가격도 저렴하게 샀어요ㅎ',
#   '너무 좋아요 애들이랑 노래도 신나게 듣고 왠만한 거는 질문할수있어서 쓸만하네요 ㅎㅎㅎ',
#   '만족합니다. 연결 하는게 그렇~~게 쉽지는 않아 조금 아쉬워요',
#   '제 친구죠~ 네이버 뮤직 정기 결제했더니벅스보다 더 다양하게 활용중이에요',
#   '만족합니다배송도 빠르고 조카 선물로 사줬는데굉장히 좋아하네요^^',
#   '빠른 배송 감사합니다.내가 사는거 보다 빠른도착어버이날 선물입니다',
#   '마음에 쏙 들어요.배송빠르고 다좋은데 크래들 없는게 좀 아쉽네요.',
#   '제일 저렴하게 구입했네요말귀도 잘 알아듣고 만족합니다',
#   '심심하지 않게 가지고 놀아요.못하는게 많음.네이버뮤직 넘비싸',
#   '배송이 좀 늦긴했지만 스피커 품질 좋아요^^',
#   '음성인식이 조금 떨어질때가 있긴한데 전반적으로 만족합니다',
#   '디자인도 예쁘고 배송도 빠르며 괜찮습니다.',
#   '음성 인식 잘 되네요. 귀엽고 스피커도 좋네요.',
#   '귀엽고 스피커 음량 좋아요',
#   '아빠 대신해서 구입해드렸는데 매우만족해하십니다.',
#   '매우 만족입니다..클로바랑 열심히 놀고있어용..',
#   '아이들이 좋아해요 지금은 방치 상태에요',
#   '가끔 인식이 잘안될때도 있지만 신기한 물건이네요~',
#   '컬러변경감사합니다인식이조금 느리지만 잘되네요',
#   '배송빠릅니다. 제품에 만족해요. 잘쓸께요',
#   '네이버 AI 스피커 프렌즈 좋와요',
#   '저렴하게잘샀어요애들이 너무 좋아해요ㅋ',
#   '동요 틀어주려고 샀는데 너무 좋아요^^',
#   '빠른배송 만족스런제품 마음에 듭니다',
#   '조카 선물했는데 너무 좋아해요ㅎ',
#   '돌잔치 선물로 구입했어요귀엽네요',
#   '친구가 생겨서좋아요마음에듭니다',
#   '응향 풍부하고컨텐츠도 많아요',
#   '너무좋아요 배송도빠르고',
#   '배송빠르게 잘받았어요.',
#   '학생 부상으로 준비한 제품',
#   '배송빠르고 좋았어요!',
#   '배송빠르고 좋아여',
#   '만족합니다^^',
#   '등록하지 않으면 별로에요. 유료결제라는 것이 그렇습니다.알았다면 안샀을 텐데.',
#   '굿',
#   '귀여워요아직사용은안해？f지만^^;',
#   '크레들 부탁했는데 안왔어요 크레들 쫌 주세요',
#   '아주 조아요',
#   '빠른배송 감사합니다 잘쓸께요',
#   '작동 잘되고요적적해하시는 부모님께 사드렸는데 생각보다 잘 쓰고계시네요^^우리 애도 노란거 사달라고 난리입니다ㅠ',
#   '흐흐흐 조아요 아이들이 너무나 조아라 하네요',
#   '음 싼건아닌듯',
#   '좋아요',
#   '브라운으로 구매했어요 잘 쓰고 있습니다',
#   '귀엽고♡다 마음에 들어요♡',
#   '좋아요',
#   '아직은 뭐가 좋은지 잘 모르겠어요',
#   '잘받았습니다. 늦었지만 지금 보이네요.........',
#   '좋아~~~~~~~~~~~',
#   '옷도 판매되었으면 좋겠어요ㅠㅠ',
#   '좋아요',
#   '이쁘네요배송 빨라요',
#   '좋와요,귀엽고 마음에 들어요',
#   '빠른 배송 감사',
#   '샐리로 잘 받았습니다~ 집에 가서 사용해볼게요~ 빠른 배송 감사합니다~',
#   '좋아요 배송빠르고 이쁩니다좋아요 배송빠르고 이쁩니다좋아요 배송빠르고 이쁩니다좋아요 배송빠르고 이쁩니다좋아요 배송빠르고 이쁩니다좋아요 배송빠르고 이쁩니다좋아요 배송빠르고 이쁩니다좋아요 배송빠르고 이쁩니다좋아요 배송빠르고 이쁩니다좋아요 배송빠르고 이쁩니다',
#   '아직 사용전~~~샐리 너무 귀엽네요',
#   '마음에 쏙 들어요.',
#   '마음에들어요',
#   '잘되네용-!!!!',
#   '아이가 너무 좋아하니 ㅋ 기쁘네요',
#   '아이들이 좋아하네요.',
#   '상품 잘 받았습니다',
#   '프리미엄 상품평 등록/수정 포토 상품평을 등록하시면, 100 스마일포인트를 드립니다.',
#   'HEREHRTTEHEHRHRTETREHETHR',
#   '아이의 꼬봉로봇이 생겼습니다',
#   '셀리가 도움이 많이됩니다.',
#   '좋은가 보네요, 사달라고 하시는 분들이 있으시네요. 잘 받았습니다. 많이 파세요.',
#   '신세계네요.. 아이들사줬는데..제가더편합니다..',
#   '궁금한거 물어보면 인식률도 좋고 낭낭한목소리로 알려주네요 ㅋ',
#   '귀여워요',
#   '브라운이 품절되었는데 여기서 구입해서 잘 썽 ㅛ브라운이 품절되었는데 여기서 구입해서 잘 썽 ㅛ브라운이 품절되었는데 여기서 구입해서 잘 썽 ㅛ브라운이 품절되었는데 여기서 구입해서 잘 썽 ㅛ',
#   '재밌고 말도 잘알아듣고 좋아요!!',
#   '겁나 빨리 오네요 마음에 듭니다 행복하세요',
#   '알면 알수록 잼나는 기계입니다 촣아요',
#   '배송 칼이네요하자없는 제품 받았어요 ♥',
#   '간단한거 물어볼때 찾게 되네요',
#   '잘 사용하겠습니다감사하비니ㅏㄷ',
#   '어디서나 들을수있어 좋아요',
#   '잘쓰고 있네요...인식률이 좋아요 좋아요',
#   '잘삿어요.ㅎㅎ']]

# %%
import pandas as pd

# %%
review = pd.Series()

# %%
def listToSeries(series, listOfList):
  import pandas as pd
  
  for list in listOfList:
    newSeries = pd.Series(list)
    series = series.append(newSeries)
  
  return series

# %%
review = listToSeries(review, TotalReview)

# %%
review.to_csv('review.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
from google.colab import files
files.download('review.csv')
